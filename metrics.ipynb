# %%
#!pip install joblib
from src.main import Analyzer

data = Analyzer(['Results/Base', 'Results/Big', 'Results/Halton2'])
# Out:
# number of failed results is 107 of 8693

# %%
# s = data.df.groupby('n_draws')[['rmse','mape']].apply(pd.DataFrame.describe).transpose()

# s = data.df.groupby('n_draws')[['rmse','mape']].describe()
# s = data.df.groupby(['n_draws','drawtype'])[['mape']].agg(["mean", "std", "min","max", "count"])
# display(s)

# def disp(df, stat, latex=False):
#     view = df.groupby(['drawtype','n_draws'])[[stat]].agg(["mean", "std", "min","max", "count"]).transpose()
#     display(view)
#     if latex: print(view)
    
# disp(data.df, "rmse")    
# disp(data.df, "mape")   
# disp(data.df, "duration")   

data.df.groupby(['n_draws','drawtype'])[['rmse','mape', 'duration']].agg(["mean", "std"]).transpose()
# Out:
# n_draws         5      10             25              50              75    \
# drawtype      halton halton pseudo  halton  pseudo  halton  pseudo  halton
# rmse     mean  0.143  0.131  0.145   0.123   0.130   0.122   0.126   0.123
#          std   0.047  0.052  0.048   0.049   0.051   0.051   0.050   0.051
# mape     mean 29.900 31.517 31.234  31.379  30.713  31.817  31.220  31.960
#          std  11.220 14.810 11.605  15.311  13.527  15.887  14.551  15.882
# duration mean 26.402 49.608 53.415 173.397 179.051 346.008 335.515 517.145
#          std  10.661 22.974 24.308  76.228  79.247 151.172 150.114 241.882
#
# n_draws                  100       250       500       1000       2000
# drawtype       pseudo  pseudo    pseudo    pseudo    pseudo     pseudo
# rmse     mean   0.123   0.126     0.119     0.120     0.119      0.119
#          std    0.050   0.050     0.049     0.047     0.048      0.048
# mape     mean  30.524  31.250    30.264    31.013    30.921     30.820
#          std   14.883  15.051    15.079    14.580    14.821     14.866
# duration mean 533.602 683.663 1,783.992 3,277.670 6,762.978 13,541.047
#          std  257.782 300.388   704.846 1,261.117 2,925.191  5,592.076
