# %%
# !pip install joblib
from src.main import Analyzer

data = Analyzer(['Results/Base', 'Results/Big', 'Results/Halton2', 'Results/Golden','Results/Sobol'])
# Out:
# number of failed results is 222 of 15778

# %%
# s = data.df.groupby('n_draws')[['rmse','mape']].apply(pd.DataFrame.describe).transpose()

# s = data.df.groupby('n_draws')[['rmse','mape']].describe()
# s = data.df.groupby(['n_draws','drawtype'])[['mape']].agg(["mean", "std", "min","max", "count"])
# display(s)

# def disp(df, stat, latex=False):
#     view = df.groupby(['drawtype','n_draws'])[[stat]].agg(["mean", "std", "min","max", "count"]).transpose()
#     display(view)
#     if latex: print(view)
    
# disp(data.df, "rmse")    
# disp(data.df, "mape")   
# disp(data.df, "duration")   

# table = data.df.groupby(['n_draws','drawtype'])[['rmse','mape', 'duration']].agg(["mean", "std", "count"]).transpose()

table = data.df.groupby(['n_draws','drawtype'])[['rmse','mape','duration']].agg(["mean", "std", "count"]).transpose().stack()

display(table)
print('\n')
print(table.to_latex())
# Out:
# n_draws                    5       10      25      50      75      100   \
#                drawtype
# rmse     mean  golden     0.164   0.147   0.140     nan     nan     nan
#                halton     0.142   0.129   0.123   0.121   0.120   0.121
#                pseudo     0.160   0.145   0.130   0.126   0.123   0.126
#                sobol      0.150   0.133   0.127     nan     nan     nan
#          std   golden     0.043   0.049   0.052     nan     nan     nan
#                halton     0.048   0.051   0.049   0.049   0.050   0.049
#                pseudo     0.042   0.048   0.051   0.050   0.050   0.050
#                sobol      0.046   0.052   0.052     nan     nan     nan
#          count golden   496.000 492.000 494.000     nan     nan     nan
#                halton   981.000 985.000 983.000 986.000 985.000 988.000
#                pseudo   975.000 979.000 986.000 992.000 992.000 991.000
#                sobol    494.000 495.000 489.000     nan     nan     nan
# ...
