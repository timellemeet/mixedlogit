# %%
#!pip install pathvalidate
# %cd C:\\Users\\Tim\\Code\\mixedlogit
from src.main import Mixedlogit, datasetloader 

dataset = datasetloader("n 1000 - seed 1234 - time 2019-06-19-154935.pickle")

mixedlogit = Mixedlogit(dataset, "bigbatch").fit(drawtype="pseudo", n_draws=100, verbose=1, save="Base", start=912, end=1000)
# Out:
# C:\Users\Tim\Code\mixedlogit
# Fitting 100 datasets
#
# Fitting model 1 of 100
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 0  0.717  0.392 -0.385   0.704   0.230    0.234   1.434   1.674    1.899
#
#      MAPE  RMSE
# 0 289.500 0.899
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 1  0.910  0.073 -0.996   0.897   0.574   -0.832   1.146   1.514    0.899
#
#      MAPE  RMSE
# 1 199.885 0.597
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 2  0.865  0.101 -0.958   0.924   0.617   -0.893   1.119   1.484    0.867
#
#      MAPE  RMSE
# 2 193.078 0.578
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 3  0.906  0.059 -0.864   1.033   0.822   -0.937   0.985   1.321    0.897
#
#      MAPE  RMSE
# 3 176.874 0.508
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 4  1.058  0.290 -0.865   1.139   1.222   -0.869   0.734   0.939    0.841
#
# ...
