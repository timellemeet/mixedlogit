# %%
#!pip install pathvalidate
# %cd C:\\Users\\tim\\Code\\mixedlogit
from src.main import Mixedlogit, datasetloader 

dataset = datasetloader("n 1000 - seed 1234 - time 2019-06-19-154935.pickle")

mixedlogit = Mixedlogit(dataset, "bigbatch").fit(drawtype="pseudo", n_draws=500, verbose=1, save="Big", start=511, end=750)
# Out:
# C:\Users\tim\Code\mixedlogit
# Fitting 250 datasets
#
# Fitting model 1 of 250
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 0  0.940  0.370 -0.170   0.308   0.515    0.584   1.959   1.717    1.726
#
#      MAPE  RMSE
# 0 355.225 1.008
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 1  0.643  0.182 -0.364   0.506   0.715   -0.272   1.565   1.487    0.912
#
#      MAPE  RMSE
# 1 234.115 0.663
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 2  0.598  0.215 -0.387   0.568   0.763   -0.480   1.483   1.415    0.723
#
#      MAPE  RMSE
# 2 209.110 0.601
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 3  0.564  0.047 -0.206   0.696   0.868   -0.481   1.281   1.255    0.549
#
#      MAPE  RMSE
# 3 184.926 0.507
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 4  0.580  0.102 -0.219   1.063   1.192   -0.452   0.716   0.818    0.550
#
#      MAPE  RMSE
# 4 107.591 0.288
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 5  0.522  0.106 -0.259   0.853   1.047   -0.425   0.532   0.606    0.515
#
#     MAPE  RMSE
# 5 79.276 0.217
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 6  0.613  0.081 -0.199   0.869   0.923   -0.523   0.504   0.535    0.530
#
#     MAPE  RMSE
# 6 76.737 0.215
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 7  0.561  0.053 -0.347   0.958   0.996   -0.544   0.564   0.411    0.459
#
#     MAPE  RMSE
# 7 80.455 0.207
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 8  0.675  0.066 -0.284   0.807   1.166   -0.629   0.492   0.463    0.449
#
#     MAPE  RMSE
# 8 71.861 0.184
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 9  0.702  0.091 -0.294   0.849   1.092   -0.632   0.373   0.617    0.416
#
#     MAPE  RMSE
# 9 55.894 0.149
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 10  0.736  0.091 -0.344   0.901   1.107   -0.616   0.360   0.520    0.382
#
#      MAPE  RMSE
# 10 48.283 0.124
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 11  0.799  0.106 -0.438   0.994   1.115   -0.585   0.293   0.402    0.288
#
#      MAPE  RMSE
# 11 35.152 0.093
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 12  0.828  0.111 -0.497   1.034   1.119   -0.578   0.251   0.296    0.222
#
#      MAPE  RMSE
# 12 31.579 0.105
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 13  0.828  0.109 -0.509   1.034   1.119   -0.570   0.232   0.239    0.188
#
#      MAPE  RMSE
# 13 32.151 0.116
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 14  0.821  0.110 -0.503   1.033   1.116   -0.568   0.214   0.189    0.160
#
#      MAPE  RMSE
# 14 32.249 0.129
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 15  0.817  0.106 -0.503   1.024   1.113   -0.554   0.198   0.157    0.141
#
#      MAPE  RMSE
# 15 31.751 0.136
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 16  0.815  0.108 -0.500   1.026   1.113   -0.560   0.190   0.139    0.132
#
#      MAPE  RMSE
# 16 31.605 0.142
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 17  0.815  0.108 -0.501   1.027   1.113   -0.559   0.186   0.133    0.129
#
#      MAPE  RMSE
# 17 31.374 0.143
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 18  0.816  0.108 -0.503   1.028   1.113   -0.558   0.178   0.123    0.125
#
#      MAPE  RMSE
# 18 30.971 0.146
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 19  0.816  0.109 -0.504   1.029   1.113   -0.557   0.172   0.116    0.124
#
#      MAPE  RMSE
# 19 30.510 0.148
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 20  0.816  0.109 -0.505   1.029   1.113   -0.557   0.162   0.105    0.123
#
#      MAPE  RMSE
# 20 29.739 0.151
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 21  0.816  0.109 -0.505   1.029   1.114   -0.557   0.148   0.091    0.123
#
#      MAPE  RMSE
# 21 28.428 0.154
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 22  0.816  0.109 -0.504   1.029   1.114   -0.557   0.124   0.070    0.126
#
#      MAPE  RMSE
# 22 26.166 0.160
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 23  0.816  0.109 -0.502   1.028   1.114   -0.559   0.094   0.046    0.134
#
#      MAPE  RMSE
# 23 24.234 0.166
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 24  0.816  0.108 -0.500   1.027   1.114   -0.559   0.081   0.037    0.138
#
#      MAPE  RMSE
# 24 25.734 0.169
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 25  0.815  0.108 -0.500   1.026   1.114   -0.560   0.075   0.032    0.138
#
#      MAPE  RMSE
# 25 26.506 0.170
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 26  0.815  0.108 -0.499   1.026   1.114   -0.560   0.064   0.025    0.138
#
#      MAPE  RMSE
# 26 27.846 0.172
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 27  0.815  0.108 -0.500   1.026   1.114   -0.559   0.055   0.020    0.137
#
#      MAPE  RMSE
# 27 29.014 0.174
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 28  0.815  0.108 -0.500   1.027   1.114   -0.559   0.047   0.015    0.136
#
#      MAPE  RMSE
# 28 30.017 0.176
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 29  0.815  0.108 -0.500   1.027   1.114   -0.559   0.043   0.013    0.136
#
#      MAPE  RMSE
# 29 30.550 0.177
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 30  0.815  0.108 -0.500   1.027   1.114   -0.559   0.038   0.011    0.137
#
#      MAPE  RMSE
# 30 31.077 0.178
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 31  0.815  0.108 -0.500   1.027   1.114   -0.559   0.040   0.012    0.136
#
#      MAPE  RMSE
# 31 30.890 0.177
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 32  0.815  0.108 -0.500   1.027   1.114   -0.559   0.041   0.012    0.136
#
#      MAPE  RMSE
# 32 30.811 0.177
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 33  0.815  0.108 -0.500   1.027   1.114   -0.559   0.041   0.012    0.136
#
#      MAPE  RMSE
# 33 30.826 0.177
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 34  0.815  0.108 -0.500   1.027   1.114   -0.559   0.041   0.012    0.136
#
#      MAPE  RMSE
# 34 30.838 0.177
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 35  0.815  0.108 -0.500   1.027   1.114   -0.559   0.040   0.011    0.136
#
#      MAPE  RMSE
# 35 30.882 0.178
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 36  0.815  0.108 -0.500   1.027   1.114   -0.559   0.041   0.009    0.136
#
#      MAPE  RMSE
# 36 30.832 0.178
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 37  0.815  0.108 -0.500   1.027   1.115   -0.559   0.043   0.007    0.136
#
#      MAPE  RMSE
# 37 30.752 0.179
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 38  0.815  0.108 -0.500   1.027   1.115   -0.559   0.046   0.005    0.136
#
#      MAPE  RMSE
# 38 30.441 0.179
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 39  0.815  0.108 -0.500   1.027   1.114   -0.559   0.054   0.002    0.136
#
#      MAPE  RMSE
# 39 29.587 0.180
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 40  0.815  0.108 -0.500   1.027   1.114   -0.559   0.068   0.001    0.136
#
#      MAPE  RMSE
# 40 27.981 0.180
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 41  0.815  0.108 -0.500   1.027   1.114   -0.559   0.069   0.001    0.137
#
#      MAPE  RMSE
# 41 27.931 0.180
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 42  0.815  0.108 -0.500   1.027   1.114   -0.559   0.069   0.001    0.137
#
#      MAPE  RMSE
# 42 27.854 0.180
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 43  0.816  0.108 -0.500   1.027   1.114   -0.559   0.070   0.001    0.137
#
#      MAPE  RMSE
# 43 27.791 0.180
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 44  0.816  0.108 -0.500   1.027   1.114   -0.559   0.070   0.001    0.137
#
#      MAPE  RMSE
# 44 27.791 0.180
# Optimization done, time elapsed: 0:38:23
#       c_0: array([0.3871419 , 0.72680844, 0.42971341, 0.26003305, 0.45536726,
#        0.68865655, 0.74667764, 0.58959949, 0.99571665])
#       dgp: 'bigbatch'
#     dgp_i: 500
#     dgp_n: 1000
#  drawtype: 'pseudo'
#  duration: 2302.900229215622
#       fun: 3386.8586223118864
#  hess_inv: array([[ 6.70685002e-03,  1.11553875e-03,  4.26677005e-03,
#         -1.16088335e-03,  4.35858588e-04, -2.86324270e-03,
#         -5.13435040e-03,  4.73576189e-02,  3.02991392e-03],
#        [ 1.11553875e-03,  3.25344105e-03,  1.58757881e-03,
#         -5.47577124e-04, -2.04145783e-05,  3.73685830e-04,
#          1.18371950e-02, -4.38000517e-02,  4.21400766e-04],
#        [ 4.26677005e-03,  1.58757881e-03,  6.40836654e-03,
#         -1.05426586e-03, -3.31005960e-04, -1.76442149e-03,
#          7.10415251e-03, -2.67410297e-02,  2.12398436e-03],
#        [-1.16088335e-03, -5.47577124e-04, -1.05426586e-03,
#          8.90550712e-03, -1.28724182e-03,  8.05647804e-04,
#         -3.35915297e-02,  1.19040663e-01,  3.83165977e-03],
#        [ 4.35858588e-04, -2.04145783e-05, -3.31005960e-04,
#         -1.28724182e-03,  1.04390739e-02, -3.44155641e-04,
#          1.19322339e-02,  2.90249134e-02,  5.33153751e-03],
#        [-2.86324270e-03,  3.73685830e-04, -1.76442149e-03,
#          8.05647804e-04, -3.44155641e-04,  2.05934624e-03,
#         -5.26741814e-03,  2.37839318e-02, -1.25604681e-03],
#        [-5.13435040e-03,  1.18371950e-02,  7.10415251e-03,
#         -3.35915297e-02,  1.19322339e-02, -5.26741814e-03,
#          1.19836975e+01, -7.06164968e+01, -2.07718023e-01],
#        [ 4.73576189e-02, -4.38000517e-02, -2.67410297e-02,
#          1.19040663e-01,  2.90249134e-02,  2.37839318e-02,
#         -7.06164968e+01,  4.20068484e+02,  6.74001306e-01],
#        [ 3.02991392e-03,  4.21400766e-04,  2.12398436e-03,
#          3.83165977e-03,  5.33153751e-03, -1.25604681e-03,
#         -2.07718023e-01,  6.74001306e-01,  1.54796805e-01]])
#       jac: array([-2.04467773e-03, -6.40869141e-04, -1.15966797e-03,  7.32421875e-04,
#        -1.19018555e-03, -7.69042969e-03,  1.22070312e-04,  6.10351562e-05,
#         1.67846680e-03])
#   message: 'Desired error not necessarily achieved due to precision loss.'
#    method: 'BFGS'
#   n_draws: 500
#      nfev: 760
#       nit: 45
#      njev: 69
#    status: 2
#   success: False
#    true_c: [0.8, 0.2, -0.5, 0.9, 1.1, -0.5, 0.1, 0.5, 0.25]
#         x: array([ 8.15502372e-01,  1.08318339e-01, -5.00297825e-01,  1.02678595e+00,
#         1.11423716e+00, -5.59204026e-01,  7.00650347e-02,  9.37305637e-04,
#         1.36733163e-01])
# Saving run 1 of 250
#
# Fitting model 2 of 250
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 0  0.773  0.235  0.001   0.838   0.681    0.490   1.292   2.433    1.668
#
#      MAPE  RMSE
# 0 278.879 0.976
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 1  0.485  0.295 -0.222   0.970   0.798   -0.292   1.051   1.869    0.752
#
#      MAPE  RMSE
# 1 182.770 0.611
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 2  0.598 -0.033 -0.231   1.043   0.897   -0.521   0.924   1.573    0.452
#
#      MAPE  RMSE
# 2 150.401 0.483
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 3  0.693  0.105 -0.113   1.070   1.032   -0.413   0.791   1.251    0.351
#
#      MAPE  RMSE
# 3 118.088 0.375
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 4  0.961  0.200  0.092   0.973   1.388   -0.637   0.570   0.746    0.389
#
#     MAPE  RMSE
# 4 86.109 0.295
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 5  0.840  0.104 -0.039   0.787   1.479   -0.563   0.424   0.500    0.421
#
#     MAPE  RMSE
# 5 66.323 0.240
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 6  0.809  0.060 -0.102   0.947   1.215   -0.543   0.316   0.355    0.464
#
#     MAPE  RMSE
# 6 56.187 0.185
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 7  0.777  0.096 -0.152   0.887   1.140   -0.533   0.283   0.361    0.427
#
#     MAPE  RMSE
# 7 46.359 0.156
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 8  0.638  0.103 -0.328   1.103   1.293   -0.454   0.237   0.386    0.401
#
#     MAPE  RMSE
# 8 41.381 0.149
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 9  0.782  0.157 -0.373   1.054   1.334   -0.473   0.124   0.671    0.371
#
#     MAPE  RMSE
# 9 22.109 0.126
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 10  0.797  0.163 -0.529   1.059   1.214   -0.451   0.402   0.234    0.307
#
#      MAPE  RMSE
# 10 48.882 0.152
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 11  0.793  0.172 -0.491   1.036   1.272   -0.467   0.211   0.370    0.316
#
#      MAPE  RMSE
# 11 24.156 0.096
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 12  0.802  0.174 -0.457   1.024   1.292   -0.471   0.139   0.552    0.316
#
#      MAPE  RMSE
# 12 14.919 0.084
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 13  0.799  0.173 -0.470   1.030   1.282   -0.470   0.143   0.523    0.313
#
#      MAPE  RMSE
# 13 14.381 0.081
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 14  0.798  0.173 -0.474   1.032   1.279   -0.469   0.135   0.546    0.310
#
#      MAPE  RMSE
# 14 13.769 0.081
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 15  0.799  0.172 -0.473   1.032   1.278   -0.469   0.136   0.542    0.310
#
#      MAPE  RMSE
# 15 13.841 0.080
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 16  0.799  0.172 -0.473   1.031   1.278   -0.469   0.136   0.541    0.310
#
#      MAPE  RMSE
# 16 13.813 0.080
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 17  0.799  0.172 -0.473   1.031   1.278   -0.469   0.135   0.542    0.310
#
#      MAPE  RMSE
# 17 13.749 0.080
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 18  0.799  0.172 -0.473   1.031   1.278   -0.469   0.134   0.542    0.310
#
#      MAPE  RMSE
# 18 13.656 0.080
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 19  0.799  0.172 -0.472   1.031   1.278   -0.469   0.133   0.542    0.309
#
#      MAPE  RMSE
# 19 13.486 0.080
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 20  0.799  0.172 -0.472   1.031   1.278   -0.469   0.130   0.542    0.309
#
#      MAPE  RMSE
# 20 13.180 0.080
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 21  0.799  0.172 -0.472   1.031   1.278   -0.469   0.125   0.541    0.309
#
#      MAPE  RMSE
# 21 12.616 0.080
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 22  0.799  0.172 -0.472   1.031   1.278   -0.469   0.115   0.541    0.309
#
#      MAPE  RMSE
# 22 11.552 0.080
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 23  0.799  0.172 -0.472   1.031   1.278   -0.469   0.110   0.541    0.310
#
#      MAPE  RMSE
# 23 11.008 0.079
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 24  0.799  0.172 -0.472   1.031   1.278   -0.469   0.107   0.541    0.310
#
#      MAPE  RMSE
# 24 10.615 0.079
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 25  0.799  0.172 -0.472   1.031   1.278   -0.469   0.107   0.541    0.310
#
#      MAPE  RMSE
# 25 10.600 0.079
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 26  0.799  0.172 -0.472   1.031   1.278   -0.469   0.107   0.541    0.310
#
#      MAPE  RMSE
# 26 10.619 0.079
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 27  0.799  0.172 -0.472   1.031   1.278   -0.469   0.107   0.541    0.310
#
#      MAPE  RMSE
# 27 10.667 0.079
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 28  0.799  0.172 -0.472   1.031   1.278   -0.469   0.107   0.541    0.310
#
#      MAPE  RMSE
# 28 10.671 0.079
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 29  0.799  0.172 -0.472   1.031   1.278   -0.469   0.107   0.541    0.310
#
#      MAPE  RMSE
# 29 10.668 0.079
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 30  0.799  0.172 -0.472   1.031   1.278   -0.469   0.107   0.541    0.310
#
#      MAPE  RMSE
# 30 10.675 0.079
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 31  0.799  0.172 -0.472   1.031   1.278   -0.469   0.107   0.541    0.310
#
#      MAPE  RMSE
# 31 10.675 0.079
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 32  0.799  0.172 -0.472   1.031   1.278   -0.469   0.107   0.541    0.310
#
#      MAPE  RMSE
# 32 10.675 0.079
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 33  0.799  0.172 -0.472   1.031   1.278   -0.469   0.107   0.541    0.310
#
#      MAPE  RMSE
# 33 10.675 0.079
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 34  0.799  0.172 -0.472   1.031   1.278   -0.469   0.107   0.541    0.310
#
#      MAPE  RMSE
# 34 10.675 0.079
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 35  0.799  0.172 -0.472   1.031   1.278   -0.469   0.107   0.541    0.310
#
#      MAPE  RMSE
# 35 10.675 0.079
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 36  0.799  0.172 -0.472   1.031   1.278   -0.469   0.107   0.541    0.310
#
#      MAPE  RMSE
# 36 10.675 0.079
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 37  0.799  0.172 -0.472   1.031   1.278   -0.469   0.107   0.541    0.310
#
#      MAPE  RMSE
# 37 10.675 0.079
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 38  0.799  0.172 -0.472   1.031   1.278   -0.469   0.107   0.541    0.310
#
#      MAPE  RMSE
# 38 10.675 0.079
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 39  0.799  0.172 -0.472   1.031   1.278   -0.469   0.107   0.541    0.310
#
#      MAPE  RMSE
# 39 10.675 0.079
# Optimization done, time elapsed: 1:16:03
#       c_0: array([0.2564811 , 0.00482579, 0.8027346 , 0.82811536, 0.66083186,
#        0.62181095, 0.29247388, 0.94300237, 0.7006791 ])
#       dgp: 'bigbatch'
#     dgp_i: 501
#     dgp_n: 1000
#  drawtype: 'pseudo'
#  duration: 4562.758589744568
#       fun: 3411.2873415087133
#  hess_inv: array([[ 3.94691137e-03,  3.66939165e-04,  9.23543722e-04,
#         -1.61479084e-03, -1.04277807e-03, -1.80452744e-03,
#         -3.08183326e-04, -3.47549749e-03, -2.52150347e-03],
#        [ 3.66939165e-04,  1.87211206e-03, -8.36933392e-04,
#         -8.08018450e-04, -4.15170944e-04,  1.69924801e-04,
#         -2.22122812e-03,  1.89094014e-03,  9.04953032e-04],
#        [ 9.23543722e-04, -8.36933392e-04,  1.38186876e-03,
#         -1.58722426e-03,  6.80512731e-04, -9.37074100e-04,
#          4.86614186e-04, -1.81673249e-03, -1.16666613e-03],
#        [-1.61479084e-03, -8.08018450e-04, -1.58722426e-03,
#          8.42687968e-03, -5.46435785e-04,  1.07672361e-03,
#         -1.59248955e-03,  4.71458556e-03, -3.33222894e-04],
#        [-1.04277807e-03, -4.15170944e-04,  6.80512731e-04,
#         -5.46435785e-04,  4.32156412e-03,  1.20082099e-05,
#         -1.66973987e-03, -1.26339222e-03, -2.27026178e-03],
#        [-1.80452744e-03,  1.69924801e-04, -9.37074100e-04,
#          1.07672361e-03,  1.20082099e-05,  1.94470618e-03,
#         -2.40183708e-04,  2.49641072e-03,  9.76842922e-04],
#        [-3.08183326e-04, -2.22122812e-03,  4.86614186e-04,
#         -1.59248955e-03, -1.66973987e-03, -2.40183708e-04,
#          2.39593982e-02, -1.33563000e-02, -4.21479316e-03],
#        [-3.47549749e-03,  1.89094014e-03, -1.81673249e-03,
#          4.71458556e-03, -1.26339222e-03,  2.49641072e-03,
#         -1.33563000e-02,  1.68934500e-02,  7.60114024e-03],
#        [-2.52150347e-03,  9.04953032e-04, -1.16666613e-03,
#         -3.33222894e-04, -2.27026178e-03,  9.76842922e-04,
#         -4.21479316e-03,  7.60114024e-03,  9.84820106e-03]])
#       jac: array([ 2.44140625e-04,  3.96728516e-04,  1.22070312e-04, -9.15527344e-05,
#         1.22070312e-04,  2.44140625e-04, -3.05175781e-05, -3.05175781e-05,
#         2.13623047e-04])
#   message: 'Desired error not necessarily achieved due to precision loss.'
#    method: 'BFGS'
#   n_draws: 500
#      nfev: 1452
#       nit: 40
#      njev: 131
#    status: 2
#   success: False
#    true_c: [0.8, 0.2, -0.5, 0.9, 1.1, -0.5, 0.1, 0.5, 0.25]
#         x: array([ 0.79862846,  0.17220975, -0.47229318,  1.03109543,  1.27807181,
#        -0.46929542,  0.10739809,  0.54108033,  0.30989979])
# Saving run 2 of 250
#
# Fitting model 3 of 250
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 0  0.893  0.404 -0.190   0.107   0.456    0.249   1.060   2.051    1.416
#
#      MAPE  RMSE
# 0 245.391 0.846
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 1  0.704  0.422 -0.341   0.317   0.540   -0.190   1.082   1.926    0.908
#
#      MAPE  RMSE
# 1 206.967 0.688
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 2  0.797 -0.124 -0.552   0.698   0.760   -0.807   1.006   1.561    0.249
#
#      MAPE  RMSE
# 2 156.211 0.506
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 3  0.705  0.115 -0.548   1.140   1.005   -0.433   0.966   1.269    0.111
#
#      MAPE  RMSE
# 3 132.063 0.401
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 4  0.724  0.251 -0.480   1.008   1.057   -0.435   0.865   1.137    0.094
#
#      MAPE  RMSE
# 4 113.592 0.340
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 5  0.645  0.231 -0.546   0.929   1.074   -0.393   0.826   1.073    0.091
#
#      MAPE  RMSE
# 5 108.282 0.320
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 6  0.636  0.216 -0.559   0.963   1.092   -0.397   0.754   0.989    0.095
#
#     MAPE  RMSE
# 6 97.970 0.286
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 7  0.645  0.222 -0.554   0.962   0.980   -0.396   0.681   0.977    0.094
#
#     MAPE  RMSE
# 7 90.998 0.268
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 8  0.656  0.223 -0.550   0.950   0.992   -0.400   0.657   0.989    0.095
#
#     MAPE  RMSE
# 8 87.979 0.263
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 9  0.697  0.223 -0.529   0.913   0.999   -0.414   0.711   0.871    0.098
#
#     MAPE  RMSE
# 9 89.322 0.250
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 10  0.712  0.224 -0.535   0.895   1.049   -0.423   0.642   0.908    0.108
#
#      MAPE  RMSE
# 10 81.253 0.235
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 11  0.732  0.221 -0.549   0.878   1.115   -0.438   0.551   0.978    0.143
#
#      MAPE  RMSE
# 11 70.482 0.225
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 12  0.768  0.211 -0.572   0.848   1.223   -0.469   0.414   1.097    0.258
#
#      MAPE  RMSE
# 12 53.708 0.231
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 13  0.734  0.242 -0.571   0.893   1.219   -0.436   0.378   1.104    0.252
#
#      MAPE  RMSE
# 13 51.894 0.229
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 14  0.698  0.255 -0.571   0.904   1.196   -0.416   0.301   1.084    0.292
#
#      MAPE  RMSE
# 14 46.104 0.215
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 15  0.655  0.254 -0.553   0.912   1.087   -0.395   0.266   0.973    0.264
#
#      MAPE  RMSE
# 15 38.400 0.179
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 16  0.683  0.243 -0.550   0.919   1.103   -0.412   0.270   0.981    0.282
#
#      MAPE  RMSE
# 16 38.406 0.179
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 17  0.685  0.241 -0.550   0.912   1.099   -0.415   0.276   0.979    0.284
#
#      MAPE  RMSE
# 17 38.635 0.178
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 18  0.687  0.239 -0.549   0.910   1.097   -0.417   0.284   0.977    0.284
#
#      MAPE  RMSE
# 18 39.410 0.178
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 19  0.696  0.232 -0.547   0.901   1.087   -0.425   0.390   0.962    0.282
#
#      MAPE  RMSE
# 19 50.015 0.188
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 20  0.694  0.234 -0.548   0.903   1.087   -0.423   0.436   0.962    0.281
#
#      MAPE  RMSE
# 20 55.330 0.197
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 21  0.685  0.241 -0.551   0.912   1.092   -0.415   0.440   0.969    0.282
#
#      MAPE  RMSE
# 21 56.771 0.200
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 22  0.683  0.243 -0.553   0.914   1.097   -0.413   0.454   0.976    0.281
#
#      MAPE  RMSE
# 22 58.587 0.205
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 23  0.683  0.243 -0.552   0.914   1.097   -0.413   0.447   0.976    0.281
#
#      MAPE  RMSE
# 23 57.830 0.204
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 24  0.683  0.243 -0.552   0.914   1.097   -0.413   0.449   0.975    0.281
#
#      MAPE  RMSE
# 24 58.019 0.204
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 25  0.683  0.243 -0.552   0.914   1.097   -0.413   0.449   0.975    0.281
#
#      MAPE  RMSE
# 25 58.026 0.204
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 26  0.683  0.243 -0.552   0.914   1.097   -0.413   0.449   0.975    0.281
#
#      MAPE  RMSE
# 26 58.025 0.204
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 27  0.683  0.243 -0.552   0.914   1.097   -0.413   0.449   0.975    0.281
#
#      MAPE  RMSE
# 27 58.025 0.204
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 28  0.683  0.243 -0.552   0.914   1.097   -0.413   0.449   0.975    0.281
#
#      MAPE  RMSE
# 28 58.025 0.204
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 29  0.683  0.243 -0.552   0.914   1.097   -0.413   0.449   0.975    0.281
#
#      MAPE  RMSE
# 29 58.025 0.204
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 30  0.683  0.243 -0.552   0.914   1.097   -0.413   0.449   0.975    0.281
#
#      MAPE  RMSE
# 30 58.025 0.204
# Optimization done, time elapsed: 1:00:08
#       c_0: array([0.4645188 , 0.09379821, 0.61061225, 0.01050182, 0.42060554,
#        0.46461448, 0.05589892, 0.74837153, 0.55310163])
#       dgp: 'bigbatch'
#     dgp_i: 502
#     dgp_n: 1000
#  drawtype: 'pseudo'
#  duration: 3607.98281788826
#       fun: 3437.7708138120547
#  hess_inv: array([[ 2.94819281e-02,  2.45272677e-02,  4.07433667e-02,
#          2.68430686e-02, -1.60293958e-02, -2.26822423e-03,
#          2.27204399e-02,  1.13536636e-02,  3.47228227e-02],
#        [ 2.45272677e-02,  2.59617006e-02,  3.74277040e-02,
#          2.68260157e-02, -1.39521350e-02,  5.87101518e-04,
#          2.19290657e-02,  9.72349233e-03,  3.52365204e-02],
#        [ 4.07433667e-02,  3.74277040e-02,  6.19291077e-02,
#          4.02273486e-02, -2.32237506e-02, -1.58205611e-03,
#          3.05912345e-02,  1.89446699e-02,  5.36918915e-02],
#        [ 2.68430686e-02,  2.68260157e-02,  4.02273486e-02,
#          3.99380818e-02, -1.69801751e-02,  1.08870738e-03,
#          2.15191350e-02,  1.39135912e-02,  4.05032805e-02],
#        [-1.60293958e-02, -1.39521350e-02, -2.32237506e-02,
#         -1.69801751e-02,  1.87595440e-02,  9.33311048e-04,
#         -6.32737341e-04, -1.07732181e-02, -3.06876327e-02],
#        [-2.26822423e-03,  5.87101518e-04, -1.58205611e-03,
#          1.08870738e-03,  9.33311048e-04,  2.24800585e-03,
#          2.72488024e-04, -7.25894479e-04,  2.95003262e-05],
#        [ 2.27204399e-02,  2.19290657e-02,  3.05912345e-02,
#          2.15191350e-02, -6.32737341e-04,  2.72488024e-04,
#          7.42413647e-02,  7.20501788e-03,  1.05604195e-02],
#        [ 1.13536636e-02,  9.72349233e-03,  1.89446699e-02,
#          1.39135912e-02, -1.07732181e-02, -7.25894479e-04,
#          7.20501788e-03,  1.21326278e-02,  2.06258023e-02],
#        [ 3.47228227e-02,  3.52365204e-02,  5.36918915e-02,
#          4.05032805e-02, -3.06876327e-02,  2.95003262e-05,
#          1.05604195e-02,  2.06258023e-02,  6.30567118e-02]])
#       jac: array([2.13623047e-04, 2.13623047e-04, 0.00000000e+00, 6.10351562e-05,
#        1.22070312e-04, 1.83105469e-04, 6.10351562e-05, 2.44140625e-04,
#        1.83105469e-04])
#   message: 'Desired error not necessarily achieved due to precision loss.'
#    method: 'BFGS'
#   n_draws: 500
#      nfev: 1145
#       nit: 31
#      njev: 103
#    status: 2
#   success: False
#    true_c: [0.8, 0.2, -0.5, 0.9, 1.1, -0.5, 0.1, 0.5, 0.25]
#         x: array([ 0.6833624 ,  0.24304717, -0.55245488,  0.91400078,  1.09706055,
#        -0.412699  ,  0.44884527,  0.97549353,  0.28100329])
# Saving run 3 of 250
#
# Fitting model 4 of 250
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 0  1.172  0.416 -0.209   0.180   0.530    0.585   1.928   2.035    1.576
#
#      MAPE  RMSE
# 0 358.498 1.041
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 1  0.716  0.221 -0.691   0.474   0.722   -0.649   1.442   1.803    0.746
#
#      MAPE  RMSE
# 1 219.098 0.678
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 2  0.626  0.045 -0.560   0.629   0.823   -0.746   1.249   1.672    0.477
#
#      MAPE  RMSE
# 2 187.698 0.579
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 3  0.561  0.208 -0.598   0.949   1.049   -0.659   0.850   1.370    0.434
#
#      MAPE  RMSE
# 3 121.388 0.401
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 4  0.458 -0.021 -0.662   1.297   1.345   -0.561   0.506   1.041    0.492
#
#     MAPE  RMSE
# 4 97.265 0.321
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 5  0.452 -0.024 -0.655   1.218   1.355   -0.555   0.457   0.986    0.488
#
#     MAPE  RMSE
# 5 89.447 0.295
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 6  0.541 -0.017 -0.572   1.168   1.241   -0.609   0.370   0.933    0.492
#
#     MAPE  RMSE
# 6 74.763 0.245
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 7  0.448 -0.014 -0.606   1.140   0.988   -0.498   0.297   1.034    0.456
#
#     MAPE  RMSE
# 7 66.176 0.262
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 8  0.521  0.031 -0.532   1.092   1.082   -0.485   0.284   1.195    0.431
#
#     MAPE  RMSE
# 8 60.843 0.278
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 9  0.606  0.110 -0.454   1.105   1.014   -0.448   0.381   0.702    0.385
#
#     MAPE  RMSE
# 9 54.997 0.163
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 10  0.804  0.178 -0.426   0.849   1.078   -0.513   0.251   0.713    0.339
#
#      MAPE  RMSE
# 10 29.568 0.097
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 11  0.897  0.209 -0.410   0.895   1.132   -0.531   0.276   0.777    0.293
#
#      MAPE  RMSE
# 11 32.521 0.120
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 12  0.904  0.204 -0.411   0.884   1.105   -0.543   0.244   0.832    0.266
#
#      MAPE  RMSE
# 12 28.877 0.130
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 13  0.888  0.196 -0.418   0.887   1.106   -0.539   0.225   0.855    0.246
#
#      MAPE  RMSE
# 13 26.293 0.132
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 14  0.885  0.195 -0.419   0.889   1.103   -0.539   0.216   0.841    0.240
#
#      MAPE  RMSE
# 14 25.212 0.127
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 15  0.885  0.195 -0.419   0.889   1.103   -0.538   0.207   0.832    0.237
#
#      MAPE  RMSE
# 15 24.118 0.123
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 16  0.885  0.196 -0.419   0.890   1.104   -0.538   0.196   0.825    0.236
#
#      MAPE  RMSE
# 16 22.760 0.120
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 17  0.885  0.196 -0.419   0.891   1.104   -0.537   0.178   0.821    0.236
#
#      MAPE  RMSE
# 17 20.558 0.118
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 18  0.885  0.196 -0.419   0.892   1.105   -0.538   0.162   0.823    0.238
#
#      MAPE  RMSE
# 18 18.756 0.117
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 19  0.885  0.196 -0.419   0.892   1.104   -0.538   0.154   0.827    0.239
#
#      MAPE  RMSE
# 19 17.979 0.118
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 20  0.885  0.196 -0.419   0.892   1.105   -0.538   0.153   0.828    0.239
#
#      MAPE  RMSE
# 20 17.885 0.118
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 21  0.885  0.196 -0.419   0.892   1.104   -0.538   0.153   0.829    0.239
#
#      MAPE  RMSE
# 21 17.869 0.118
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 22  0.885  0.196 -0.419   0.892   1.104   -0.538   0.153   0.829    0.239
#
#      MAPE  RMSE
# 22 17.862 0.118
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 23  0.885  0.196 -0.419   0.892   1.104   -0.538   0.153   0.829    0.239
#
#      MAPE  RMSE
# 23 17.864 0.118
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 24  0.885  0.196 -0.419   0.892   1.104   -0.538   0.153   0.829    0.239
#
#      MAPE  RMSE
# 24 17.865 0.118
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 25  0.885  0.196 -0.419   0.892   1.104   -0.538   0.153   0.829    0.239
#
#      MAPE  RMSE
# 25 17.865 0.118
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 26  0.885  0.196 -0.419   0.892   1.104   -0.538   0.153   0.829    0.239
#
#      MAPE  RMSE
# 26 17.865 0.118
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 27  0.885  0.196 -0.419   0.892   1.104   -0.538   0.153   0.829    0.239
#
#      MAPE  RMSE
# 27 17.864 0.118
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 28  0.885  0.196 -0.419   0.892   1.104   -0.538   0.153   0.829    0.239
#
#      MAPE  RMSE
# 28 17.864 0.118
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 29  0.885  0.196 -0.419   0.892   1.104   -0.538   0.153   0.829    0.239
#
#      MAPE  RMSE
# 29 17.864 0.118
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 30  0.885  0.196 -0.419   0.892   1.104   -0.538   0.153   0.829    0.239
#
#      MAPE  RMSE
# 30 17.864 0.118
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 31  0.885  0.196 -0.419   0.892   1.104   -0.538   0.153   0.829    0.239
#
#      MAPE  RMSE
# 31 17.864 0.118
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 32  0.885  0.196 -0.419   0.892   1.104   -0.538   0.153   0.829    0.239
#
#      MAPE  RMSE
# 32 17.864 0.118
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 33  0.885  0.196 -0.419   0.892   1.104   -0.538   0.153   0.829    0.239
#
#      MAPE  RMSE
# 33 17.864 0.118
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 34  0.885  0.196 -0.419   0.892   1.104   -0.538   0.153   0.829    0.239
#
#      MAPE  RMSE
# 34 17.864 0.118
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 35  0.885  0.196 -0.419   0.892   1.104   -0.538   0.153   0.829    0.239
#
#      MAPE  RMSE
# 35 17.864 0.118
# Optimization done, time elapsed: 1:21:51
#       c_0: array([0.69062652, 0.62632657, 0.48130928, 0.1155162 , 0.48280776,
#        0.75412778, 0.76325972, 0.75614873, 0.92273284])
#       dgp: 'bigbatch'
#     dgp_i: 503
#     dgp_n: 1000
#  drawtype: 'pseudo'
#  duration: 4910.880677700043
#       fun: 3422.8245099174496
#  hess_inv: array([[ 1.55766873e-03,  6.59880117e-04,  2.10724472e-03,
#         -3.93696254e-04, -6.77603951e-04, -1.58895011e-03,
#         -1.45933566e-04,  7.18106215e-04,  3.70588926e-04],
#        [ 6.59880117e-04,  6.46305860e-04,  5.51617503e-04,
#         -2.04691106e-05, -7.81811555e-04, -5.03599166e-04,
#          5.66449371e-05,  5.29230503e-04,  1.90285087e-04],
#        [ 2.10724472e-03,  5.51617503e-04,  5.41541759e-03,
#         -2.55348492e-03,  9.88712450e-05, -2.44008773e-03,
#         -1.14105471e-03,  1.18996409e-03,  1.18698547e-03],
#        [-3.93696254e-04, -2.04691106e-05, -2.55348492e-03,
#          2.41687661e-03, -1.15768360e-03,  5.17012043e-04,
#          9.63919837e-04, -1.36023790e-04, -6.75445595e-04],
#        [-6.77603951e-04, -7.81811555e-04,  9.88712450e-05,
#         -1.15768360e-03,  3.44075009e-03,  1.54516797e-04,
#         -1.58332578e-03, -8.33880524e-04, -2.61266461e-04],
#        [-1.58895011e-03, -5.03599166e-04, -2.44008773e-03,
#          5.17012043e-04,  1.54516797e-04,  1.84804661e-03,
#          3.90187255e-04, -6.70004849e-04, -3.36479210e-04],
#        [-1.45933566e-04,  5.66449371e-05, -1.14105471e-03,
#          9.63919837e-04, -1.58332578e-03,  3.90187255e-04,
#          1.48091438e-03, -8.25808273e-05, -3.35383664e-04],
#        [ 7.18106215e-04,  5.29230503e-04,  1.18996409e-03,
#         -1.36023790e-04, -8.33880524e-04, -6.70004849e-04,
#         -8.25808273e-05,  7.97902276e-04,  3.43361371e-04],
#        [ 3.70588926e-04,  1.90285087e-04,  1.18698547e-03,
#         -6.75445595e-04, -2.61266461e-04, -3.36479210e-04,
#         -3.35383664e-04,  3.43361371e-04,  5.44710821e-04]])
#       jac: array([ 1.52587891e-04,  2.44140625e-04,  1.22070312e-04,  6.10351562e-05,
#         1.83105469e-04,  2.13623047e-04,  2.44140625e-04, -6.10351562e-05,
#         2.13623047e-04])
#   message: 'Desired error not necessarily achieved due to precision loss.'
#    method: 'BFGS'
#   n_draws: 500
#      nfev: 1552
#       nit: 36
#      njev: 140
#    status: 2
#   success: False
#    true_c: [0.8, 0.2, -0.5, 0.9, 1.1, -0.5, 0.1, 0.5, 0.25]
#         x: array([ 0.88487746,  0.19596807, -0.41903272,  0.89154821,  1.10448592,
#        -0.53767973,  0.15307596,  0.82853752,  0.23927075])
# Saving run 4 of 250
#
# Fitting model 5 of 250
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 0  0.819  0.456 -0.078   0.354   0.907    0.682   1.335   1.300    1.630
#
#      MAPE  RMSE
# 0 275.134 0.820
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 1  0.594  0.172 -0.320   0.566   1.075   -0.106   1.176   1.266    1.000
#
#      MAPE  RMSE
# 1 191.441 0.543
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 2  0.517  0.176 -0.387   0.647   1.134   -0.404   1.105   1.238    0.738
#
#      MAPE  RMSE
# 2 163.115 0.467
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 3  0.584 -0.055 -0.337   0.756   1.212   -0.428   0.991   1.177    0.504
#
#      MAPE  RMSE
# 3 150.592 0.407
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 4  0.640 -0.016 -0.303   1.027   1.405   -0.439   0.683   0.976    0.521
#
#      MAPE  RMSE
# 4 112.010 0.310
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 5  0.430 -0.063 -0.487   0.724   1.375   -0.361   0.318   0.653    0.491
#
#     MAPE  RMSE
# 5 66.369 0.226
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 6  0.498 -0.082 -0.447   0.721   1.143   -0.448   0.268   0.591    0.490
#
#     MAPE  RMSE
# 6 56.152 0.184
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 7  0.481 -0.068 -0.476   0.764   1.135   -0.441   0.272   0.599    0.472
#
#     MAPE  RMSE
# 7 54.389 0.178
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 8  0.583 -0.038 -0.424   0.689   1.256   -0.528   0.281   0.618    0.451
#
#     MAPE  RMSE
# 8 54.366 0.172
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 9  0.654  0.031 -0.430   0.740   1.244   -0.514   0.247   0.840    0.413
#
#     MAPE  RMSE
# 9 47.827 0.172
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 10  0.744  0.090 -0.515   0.882   1.289   -0.514   0.474   0.233    0.349
#
#      MAPE  RMSE
# 10 61.617 0.174
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 11  0.755  0.151 -0.519   0.900   1.232   -0.505   0.300   0.292    0.293
#
#      MAPE  RMSE
# 11 34.000 0.109
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 12  0.770  0.158 -0.499   0.905   1.272   -0.492   0.241   0.375    0.263
#
#      MAPE  RMSE
# 12 23.811 0.087
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 13  0.772  0.152 -0.480   0.902   1.285   -0.501   0.180   0.561    0.237
#
#      MAPE  RMSE
# 13 16.228 0.073
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 14  0.773  0.149 -0.487   0.895   1.277   -0.499   0.171   0.584    0.235
#
#      MAPE  RMSE
# 14 15.779 0.072
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 15  0.772  0.148 -0.493   0.895   1.275   -0.500   0.171   0.567    0.236
#
#      MAPE  RMSE
# 15 15.248 0.070
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 16  0.771  0.148 -0.493   0.897   1.276   -0.500   0.167   0.575    0.236
#
#      MAPE  RMSE
# 16 15.031 0.071
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 17  0.772  0.149 -0.493   0.898   1.277   -0.500   0.160   0.582    0.236
#
#      MAPE  RMSE
# 17 14.370 0.071
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 18  0.772  0.149 -0.493   0.900   1.279   -0.500   0.147   0.589    0.237
#
#      MAPE  RMSE
# 18 13.008 0.071
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 19  0.772  0.149 -0.493   0.901   1.280   -0.500   0.125   0.593    0.239
#
#      MAPE  RMSE
# 19 10.506 0.071
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 20  0.772  0.149 -0.492   0.901   1.280   -0.500   0.088   0.593    0.242
#
#     MAPE  RMSE
# 20 8.944 0.070
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 21  0.772  0.149 -0.492   0.899   1.279   -0.500   0.055   0.587    0.244
#
#      MAPE  RMSE
# 21 12.416 0.071
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 22  0.772  0.148 -0.491   0.897   1.277   -0.500   0.026   0.576    0.243
#
#      MAPE  RMSE
# 22 15.505 0.072
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 23  0.771  0.148 -0.491   0.896   1.276   -0.500   0.012   0.568    0.241
#
#      MAPE  RMSE
# 23 16.956 0.072
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 24  0.771  0.148 -0.491   0.896   1.275   -0.500   0.006   0.564    0.239
#
#      MAPE  RMSE
# 24 17.636 0.073
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 25  0.771  0.148 -0.490   0.896   1.275   -0.500   0.004   0.565    0.238
#
#      MAPE  RMSE
# 25 17.962 0.073
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 26  0.772  0.148 -0.490   0.897   1.276   -0.500   0.002   0.566    0.238
#
#      MAPE  RMSE
# 26 18.179 0.073
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 27  0.772  0.148 -0.490   0.897   1.276   -0.500   0.001   0.569    0.238
#
#      MAPE  RMSE
# 27 18.368 0.074
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 28  0.772  0.148 -0.491   0.897   1.276   -0.500   0.001   0.570    0.238
#
#      MAPE  RMSE
# 28 18.401 0.074
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 29  0.772  0.148 -0.491   0.897   1.277   -0.500   0.000   0.571    0.239
#
#      MAPE  RMSE
# 29 18.433 0.074
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 30  0.772  0.148 -0.491   0.897   1.276   -0.500   0.000   0.571    0.239
#
#      MAPE  RMSE
# 30 18.433 0.074
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 31  0.772  0.148 -0.491   0.897   1.276   -0.500   0.000   0.570    0.239
#
#      MAPE  RMSE
# 31 18.430 0.074
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 32  0.772  0.148 -0.491   0.897   1.276   -0.500   0.000   0.569    0.239
#
#      MAPE  RMSE
# 32 18.427 0.074
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 33  0.772  0.148 -0.491   0.897   1.276   -0.500   0.000   0.569    0.239
#
#      MAPE  RMSE
# 33 18.429 0.074
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 34  0.772  0.148 -0.491   0.897   1.276   -0.500   0.000   0.569    0.239
#
#      MAPE  RMSE
# 34 18.430 0.074
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 35  0.772  0.148 -0.491   0.897   1.276   -0.500   0.000   0.569    0.239
#
#      MAPE  RMSE
# 35 18.431 0.074
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 36  0.772  0.148 -0.491   0.897   1.276   -0.500   0.000   0.569    0.239
#
#      MAPE  RMSE
# 36 18.431 0.074
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 37  0.772  0.148 -0.491   0.897   1.276   -0.500   0.000   0.569    0.239
#
#      MAPE  RMSE
# 37 18.430 0.074
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 38  0.772  0.148 -0.491   0.897   1.276   -0.500   0.000   0.569    0.239
#
#      MAPE  RMSE
# 38 18.429 0.074
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 39  0.772  0.148 -0.491   0.897   1.276   -0.500   0.000   0.569    0.239
#
#      MAPE  RMSE
# 39 18.428 0.074
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 40  0.772  0.148 -0.491   0.897   1.276   -0.500   0.000   0.569    0.239
#
#      MAPE  RMSE
# 40 18.428 0.074
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 41  0.772  0.148 -0.491   0.897   1.276   -0.500   0.000   0.569    0.239
#
#      MAPE  RMSE
# 41 18.429 0.074
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 42  0.772  0.148 -0.491   0.897   1.276   -0.500   0.000   0.569    0.239
#
#      MAPE  RMSE
# 42 18.429 0.074
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 43  0.772  0.148 -0.491   0.897   1.276   -0.500   0.000   0.569    0.239
#
#      MAPE  RMSE
# 43 18.430 0.074
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 44  0.772  0.148 -0.491   0.897   1.276   -0.500   0.000   0.570    0.239
#
#      MAPE  RMSE
# 44 18.435 0.074
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 45  0.772  0.148 -0.491   0.897   1.276   -0.500   0.000   0.570    0.239
#
#      MAPE  RMSE
# 45 18.446 0.074
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 46  0.772  0.148 -0.491   0.897   1.276   -0.500   0.000   0.570    0.239
#
#      MAPE  RMSE
# 46 18.453 0.074
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 47  0.772  0.148 -0.491   0.897   1.276   -0.500   0.000   0.570    0.239
#
#      MAPE  RMSE
# 47 18.447 0.074
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# ...
#      MAPE  RMSE
# 27 46.034 0.157
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 28  0.860  0.158 -0.356   0.689   1.225   -0.522   0.343   0.772    0.301
#
#      MAPE  RMSE
# 28 46.034 0.157
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 29  0.860  0.158 -0.356   0.689   1.225   -0.522   0.343   0.772    0.301
#
#      MAPE  RMSE
# 29 46.034 0.157
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 30  0.860  0.158 -0.356   0.689   1.225   -0.522   0.343   0.772    0.301
#
#      MAPE  RMSE
# 30 46.034 0.157
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 31  0.860  0.158 -0.356   0.689   1.225   -0.522   0.343   0.772    0.301
#
#      MAPE  RMSE
# 31 46.034 0.157
# Optimization done, time elapsed: 0:30:40
#       c_0: array([0.61697893, 0.29413637, 0.58128082, 0.21978838, 0.54102261,
#        0.88724331, 0.46963068, 0.91589897, 0.69532546])
#       dgp: 'bigbatch'
#     dgp_i: 510
#     dgp_n: 1000
#  drawtype: 'pseudo'
#  duration: 1839.9228384494781
#       fun: 3457.9276857991654
#  hess_inv: array([[ 0.10110032,  0.03018832,  0.06410281, -0.06000939, -0.02996288,
#         -0.06178258, -0.18258117, -0.17247787,  0.1563278 ],
#        [ 0.03018832,  0.00985205,  0.01875679, -0.01827201, -0.00844684,
#         -0.01781174, -0.05444641, -0.05213363,  0.04542564],
#        [ 0.06410281,  0.01875679,  0.04148705, -0.03797685, -0.01966924,
#         -0.03900277, -0.11647464, -0.11049395,  0.09927495],
#        [-0.06000939, -0.01827201, -0.03797685,  0.03870709,  0.01737806,
#          0.03725692,  0.10701188,  0.10466717, -0.09468462],
#        [-0.02996288, -0.00844684, -0.01966924,  0.01737806,  0.00961917,
#          0.01812874,  0.05482222,  0.05175992, -0.04651366],
#        [-0.06178258, -0.01781174, -0.03900277,  0.03725692,  0.01812874,
#          0.03916678,  0.11064404,  0.10420848, -0.09777173],
#        [-0.18258117, -0.05444641, -0.11647464,  0.10701188,  0.05482222,
#          0.11064404,  0.33265694,  0.31289943, -0.28181878],
#        [-0.17247787, -0.05213363, -0.11049395,  0.10466717,  0.05175992,
#          0.10420848,  0.31289943,  0.29972631, -0.26681265],
#        [ 0.1563278 ,  0.04542564,  0.09927495, -0.09468462, -0.04651366,
#         -0.09777173, -0.28181878, -0.26681265,  0.24692386]])
#       jac: array([ 2.13623047e-04,  6.10351562e-05,  2.74658203e-04, -6.10351562e-05,
#         2.44140625e-04,  4.57763672e-04,  3.05175781e-05,  1.52587891e-04,
#         2.44140625e-04])
#   message: 'Desired error not necessarily achieved due to precision loss.'
#    method: 'BFGS'
#   n_draws: 500
#      nfev: 694
#       nit: 32
#      njev: 63
#    status: 2
#   success: False
#    true_c: [0.8, 0.2, -0.5, 0.9, 1.1, -0.5, 0.1, 0.5, 0.25]
#         x: array([ 0.85959864,  0.15844004, -0.35642431,  0.68902208,  1.22539359,
#        -0.52205975,  0.34334894,  0.7716652 ,  0.30107366])
# Saving run 11 of 250
#
# Fitting model 12 of 250
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 0  0.897  0.388 -0.328   0.940   0.638    0.062   1.091   1.118    1.222
#
#      MAPE  RMSE
# 0 200.370 0.569
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 1  0.764  0.353 -0.430   0.960   0.763   -0.293   1.028   1.097    0.798
#
#      MAPE  RMSE
# 1 160.039 0.436
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 2  0.832  0.150 -0.363   0.969   0.837   -0.306   0.967   1.029    0.573
#
#      MAPE  RMSE
# 2 136.533 0.376
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 3  1.189  0.487  0.048   0.948   0.973   -0.470   0.677   0.602    0.391
#
#      MAPE  RMSE
# 3 108.729 0.319
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 4  1.356  0.328  0.119   0.829   1.049   -0.776   0.483   0.347    0.415
#
#     MAPE  RMSE
# 4 89.392 0.332
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 5  1.298  0.316  0.072   0.775   1.093   -0.751   0.426   0.286    0.409
#
#     MAPE  RMSE
# 5 81.322 0.306
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 6  1.167  0.280 -0.047   0.976   1.047   -0.701   0.338   0.189    0.394
#
#     MAPE  RMSE
# 6 65.262 0.251
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 7  1.139  0.279 -0.064   0.938   0.939   -0.700   0.349   0.173    0.379
#
#     MAPE  RMSE
# 7 65.930 0.250
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 8  1.035  0.270 -0.163   0.934   1.036   -0.661   0.534   0.100    0.348
#
#     MAPE  RMSE
# 8 80.706 0.250
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 9  0.880  0.220 -0.339   0.929   1.072   -0.540   0.318   0.056    0.335
#
#     MAPE  RMSE
# 9 45.193 0.179
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 10  0.765  0.225 -0.487   0.922   1.187   -0.462   0.235   0.038    0.271
#
#      MAPE  RMSE
# 10 30.358 0.165
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 11  0.772  0.210 -0.493   0.922   1.168   -0.462   0.215   0.038    0.257
#
#      MAPE  RMSE
# 11 26.257 0.161
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 12  0.794  0.209 -0.478   0.925   1.157   -0.472   0.179   0.045    0.236
#
#      MAPE  RMSE
# 12 22.135 0.156
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 13  0.793  0.210 -0.474   0.923   1.157   -0.470   0.165   0.048    0.229
#
#      MAPE  RMSE
# 13 20.914 0.154
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 14  0.792  0.210 -0.473   0.923   1.157   -0.470   0.153   0.051    0.226
#
#      MAPE  RMSE
# 14 19.772 0.153
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 15  0.791  0.211 -0.472   0.922   1.158   -0.469   0.137   0.058    0.224
#
#      MAPE  RMSE
# 15 17.990 0.150
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 16  0.787  0.216 -0.463   0.918   1.162   -0.466   0.029   0.368    0.211
#
#      MAPE  RMSE
# 16 16.041 0.059
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 17  0.897  0.388 -0.328   0.940   0.638    0.062   1.091   1.118    1.222
#
#       MAPE  RMSE
# 17 200.370 0.569
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 18  0.764  0.353 -0.430   0.960   0.763   -0.293   1.028   1.097    0.798
#
#       MAPE  RMSE
# 18 160.039 0.436
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 19  0.832  0.150 -0.363   0.969   0.837   -0.306   0.967   1.029    0.573
#
#       MAPE  RMSE
# 19 136.533 0.376
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 20  1.189  0.487  0.048   0.948   0.973   -0.470   0.677   0.602    0.391
#
#       MAPE  RMSE
# 20 108.729 0.319
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 21  1.356  0.328  0.119   0.829   1.049   -0.776   0.483   0.347    0.415
#
#      MAPE  RMSE
# 21 89.392 0.332
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 22  1.298  0.316  0.072   0.775   1.093   -0.751   0.426   0.286    0.409
#
#      MAPE  RMSE
# 22 81.322 0.306
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 23  1.167  0.280 -0.047   0.976   1.047   -0.701   0.338   0.189    0.394
#
#      MAPE  RMSE
# 23 65.262 0.251
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 24  1.139  0.279 -0.064   0.938   0.939   -0.700   0.349   0.173    0.379
#
#      MAPE  RMSE
# 24 65.930 0.250
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 25  1.035  0.270 -0.163   0.934   1.036   -0.661   0.534   0.100    0.348
#
#      MAPE  RMSE
# 25 80.706 0.250
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 26  0.880  0.220 -0.339   0.929   1.072   -0.540   0.318   0.056    0.335
#
#      MAPE  RMSE
# 26 45.193 0.179
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 27  0.765  0.225 -0.487   0.922   1.187   -0.462   0.235   0.038    0.271
#
#      MAPE  RMSE
# 27 30.358 0.165
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 28  0.772  0.210 -0.493   0.922   1.168   -0.462   0.215   0.038    0.257
#
#      MAPE  RMSE
# 28 26.257 0.161
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 29  0.794  0.209 -0.478   0.925   1.157   -0.472   0.179   0.045    0.236
#
#      MAPE  RMSE
# 29 22.135 0.156
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 30  0.793  0.210 -0.474   0.923   1.157   -0.470   0.165   0.048    0.229
#
#      MAPE  RMSE
# 30 20.914 0.154
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 31  0.792  0.210 -0.473   0.923   1.157   -0.470   0.153   0.051    0.226
#
#      MAPE  RMSE
# 31 19.772 0.153
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 32  0.791  0.211 -0.472   0.922   1.158   -0.469   0.137   0.058    0.224
#
#      MAPE  RMSE
# 32 17.990 0.150
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 33  0.787  0.216 -0.463   0.918   1.162   -0.466   0.029   0.368    0.211
#
#      MAPE  RMSE
# 33 16.041 0.059
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Code\mixedlogit\src\optimize.py in mixedlogit(data, drawtype, n_draws, true_c, dgp, dgp_i, dgp_n, c_0, method, verbose)
#     112         try:
# --> 113             res =  minimize(likelihood, c_0, args=(data.drop(columns='choice').values, draws, verbose), method=method, callback=logging)
#     114         except:
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     594     elif meth == 'bfgs':
# --> 595         return _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     596     elif meth == 'newton-cg':
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, **unknown_options)
#    1006         if callback is not None:
# -> 1007             callback(xk)
#    1008         k += 1
#
# ~\Code\mixedlogit\src\optimize.py in logging(xk)
#     102                 c_i = np.concatenate((xk[:6], sigma))
# --> 103                 rmse = sqrt(mean_squared_error(true_c, c_i))
#     104                 mape = mean_absolute_percentage_error(true_c, c_i)
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput)
#     238     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 239         y_true, y_pred, multioutput)
#     240     check_consistent_length(y_true, y_pred, sample_weight)
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\regression.py in _check_reg_targets(y_true, y_pred, multioutput)
#      76     y_true = check_array(y_true, ensure_2d=False)
# ---> 77     y_pred = check_array(y_pred, ensure_2d=False)
#      78
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     572             _assert_all_finite(array,
# --> 573                                allow_nan=force_all_finite == 'allow-nan')
#     574
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan)
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-2e6192114c2d> in <module>
#       5 dataset = datasetloader("n 1000 - seed 1234 - time 2019-06-19-154935.pickle")
#       6
# ----> 7 mixedlogit = Mixedlogit(dataset, "bigbatch").fit(drawtype="pseudo", n_draws=500, verbose=1, save="Big", start=500, end=750)
#
# ~\Code\mixedlogit\src\main.py in fit(self, drawtype, n_draws, start, end, c_0, save, method, verbose)
#      52             for i in range(n_runs):
#      53                 print("Fitting model %d of %d \n" % ((i+1), n_runs))
# ---> 54                 self.result[i] = mixedlogit(self.data[i], drawtype, n_draws, true_c = self.coefficients, dgp= self.dgp, dgp_i = (start+i), dgp_n=len(self.data), verbose = verbose)
#      55
#      56                 if save != False:
#
# ~\Code\mixedlogit\src\optimize.py in mixedlogit(data, drawtype, n_draws, true_c, dgp, dgp_i, dgp_n, c_0, method, verbose)
#     113             res =  minimize(likelihood, c_0, args=(data.drop(columns='choice').values, draws, verbose), method=method, callback=logging)
#     114         except:
# --> 115             res =  minimize(likelihood, c_0, args=(data.drop(columns='choice').values, draws, verbose), method=method, callback=logging)
#     116         end = time.time()
#     117         duration = end-start
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     593         return _minimize_cg(fun, x0, args, jac, callback, **options)
#     594     elif meth == 'bfgs':
# --> 595         return _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     596     elif meth == 'newton-cg':
#     597         return _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, **unknown_options)
#    1005         gfk = gfkp1
#    1006         if callback is not None:
# -> 1007             callback(xk)
#    1008         k += 1
#    1009         gnorm = vecnorm(gfk, ord=norm)
#
# ~\Code\mixedlogit\src\optimize.py in logging(xk)
#     101                 sigma = np.exp(xk[6:])
#     102                 c_i = np.concatenate((xk[:6], sigma))
# --> 103                 rmse = sqrt(mean_squared_error(true_c, c_i))
#     104                 mape = mean_absolute_percentage_error(true_c, c_i)
#     105
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput)
#     237     """
#     238     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 239         y_true, y_pred, multioutput)
#     240     check_consistent_length(y_true, y_pred, sample_weight)
#     241     output_errors = np.average((y_true - y_pred) ** 2, axis=0,
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\regression.py in _check_reg_targets(y_true, y_pred, multioutput)
#      75     check_consistent_length(y_true, y_pred)
#      76     y_true = check_array(y_true, ensure_2d=False)
# ---> 77     y_pred = check_array(y_pred, ensure_2d=False)
#      78
#      79     if y_true.ndim == 1:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     571         if force_all_finite:
#     572             _assert_all_finite(array,
# --> 573                                allow_nan=force_all_finite == 'allow-nan')
#     574
#     575     shape_repr = _shape_repr(array.shape)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57
#      58
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
