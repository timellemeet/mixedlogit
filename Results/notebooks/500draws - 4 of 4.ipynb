# %%
#!pip install pathvalidate
# %cd C:\\Users\\tim\\Code\\mixedlogit
from src.main import Mixedlogit, datasetloader 

dataset = datasetloader("n 1000 - seed 1234 - time 2019-06-19-154935.pickle")

mixedlogit = Mixedlogit(dataset, "bigbatch").fit(drawtype="pseudo", n_draws=500, verbose=1, save="Big", start=754, end=1000)
# Out:
# C:\Users\tim\Code\mixedlogit
# Fitting 250 datasets
#
# Fitting model 1 of 250
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 0  1.166  0.357 -0.374   0.212   0.669    0.235   1.124   1.493    1.361
#
#      MAPE  RMSE
# 0 231.011 0.718
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 1  0.976  0.374 -0.559   0.462   0.782   -0.317   1.164   1.380    0.902
#
#      MAPE  RMSE
# 1 192.841 0.550
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 2  0.898  0.252 -0.674   0.666   0.885   -0.717   1.155   1.269    0.519
#
#      MAPE  RMSE
# 2 164.226 0.467
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 3  0.803  0.123 -0.760   1.295   1.177   -0.564   1.186   1.003    0.479
#
#      MAPE  RMSE
# 3 159.254 0.438
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 4  0.753  0.220 -0.730   1.358   1.227   -0.506   1.102   0.904    0.449
#
# ...
