# %%
#!pip install pathvalidate
# %cd C:\\Users\\Tim\\Code\\mixedlogit
from src.main import Mixedlogit, datasetloader 

dataset = datasetloader("n 1000 - seed 1234 - time 2019-06-19-154935.pickle")

mixedlogit = Mixedlogit(dataset, "bigbatch").fit(drawtype="pseudo", n_draws=100, verbose=1, save="Base", start=6, end=100)
# Out:
# C:\Users\Tim\Code\mixedlogit
# Fitting 100 datasets
#
# Fitting model 1 of 100
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 0  1.015  0.164 -0.466   0.148   0.638   -0.068   1.906   1.922    0.892
#
#      MAPE  RMSE
# 0 290.074 0.863
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 1  0.940  0.148 -0.684   0.297   0.720   -0.663   1.741   1.674    0.577
#
#      MAPE  RMSE
# 1 246.759 0.728
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 2  0.793  0.020 -0.475   0.493   0.844   -0.770   1.515   1.445    0.355
#
#      MAPE  RMSE
# 2 207.115 0.600
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 3  0.804  0.258 -0.462   0.781   1.013   -0.713   1.162   1.115    0.308
#
#      MAPE  RMSE
# 3 145.413 0.419
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 4  0.794  0.136 -0.474   1.213   1.263   -0.723   0.752   0.724    0.347
#
# ...
