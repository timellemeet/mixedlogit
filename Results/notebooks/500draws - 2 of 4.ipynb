# %%
#!pip install pathvalidate
# %cd C:\\Users\\tim\\Code\\mixedlogit
from src.main import Mixedlogit, datasetloader 

dataset = datasetloader("n 1000 - seed 1234 - time 2019-06-19-154935.pickle")

mixedlogit = Mixedlogit(dataset, "bigbatch").fit(drawtype="pseudo", n_draws=500, verbose=1, save="Big", start=263, end=500)
# Out:
# C:\Users\tim\Code\mixedlogit
# Fitting 250 datasets
#
# Fitting model 1 of 250
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 0  1.109  0.488  0.016   0.888   0.730    0.700   1.663   1.442    1.740
#
#      MAPE  RMSE
# 0 323.051 0.917
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 1  0.674  0.088 -0.507   0.985   0.945   -0.591   1.211   1.220    1.181
#
#      MAPE  RMSE
# 1 193.579 0.546
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 2  0.620  0.093 -0.521   0.998   0.974   -0.706   1.165   1.187    1.014
#
#      MAPE  RMSE
# 2 183.524 0.506
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 3  0.587 -0.039 -0.415   1.031   1.098   -0.689   0.938   1.010    0.963
#
#      MAPE  RMSE
# 3 160.081 0.426
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 4  0.618  0.030 -0.430   1.060   1.264   -0.676   0.678   0.785    0.956
#
#      MAPE  RMSE
# 4 122.962 0.344
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 5  0.562  0.029 -0.470   0.894   1.025   -0.642   0.514   0.627    0.916
#
#     MAPE  RMSE
# 5 95.928 0.288
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 6  0.655  0.051 -0.402   1.151   0.741   -0.709   0.435   0.544    0.879
#
#     MAPE  RMSE
# 6 89.969 0.298
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 7  0.638  0.063 -0.443   1.163   0.823   -0.681   0.371   0.553    0.713
#
#     MAPE  RMSE
# 7 73.108 0.240
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 8  0.825  0.083 -0.297   1.007   0.864   -0.821   0.385   0.503    0.692
#
#     MAPE  RMSE
# 8 73.548 0.236
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 9  0.762  0.048 -0.394   0.984   1.046   -0.686   0.619   0.193    0.531
#
#     MAPE  RMSE
# 9 93.953 0.241
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 10  0.863  0.125 -0.375   0.989   1.034   -0.562   0.228   0.397    0.405
#
#      MAPE  RMSE
# 10 34.370 0.101
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 11  0.830  0.104 -0.545   1.066   1.167   -0.610   0.195   0.224    0.269
#
#      MAPE  RMSE
# 11 29.489 0.125
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 12  0.808  0.096 -0.523   1.026   1.145   -0.550   0.180   0.170    0.219
#
#      MAPE  RMSE
# 12 27.046 0.128
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 13  0.823  0.110 -0.482   1.013   1.106   -0.570   0.155   0.154    0.187
#
#      MAPE  RMSE
# 13 25.343 0.130
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 14  0.823  0.110 -0.489   1.027   1.113   -0.567   0.140   0.139    0.165
#
#      MAPE  RMSE
# 14 25.020 0.137
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 15  0.818  0.109 -0.501   1.025   1.114   -0.562   0.128   0.127    0.149
#
#      MAPE  RMSE
# 15 24.283 0.141
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 16  0.818  0.109 -0.500   1.028   1.116   -0.561   0.121   0.122    0.141
#
#      MAPE  RMSE
# 16 23.985 0.143
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 17  0.817  0.109 -0.501   1.027   1.114   -0.561   0.117   0.121    0.138
#
#      MAPE  RMSE
# 17 23.650 0.143
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 18  0.817  0.109 -0.500   1.027   1.114   -0.561   0.114   0.121    0.137
#
#      MAPE  RMSE
# 18 23.364 0.143
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 19  0.817  0.109 -0.500   1.027   1.114   -0.560   0.109   0.123    0.135
#
#      MAPE  RMSE
# 19 22.828 0.143
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 20  0.817  0.109 -0.500   1.027   1.114   -0.560   0.101   0.127    0.134
#
#      MAPE  RMSE
# 20 21.877 0.142
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 21  0.817  0.109 -0.500   1.027   1.114   -0.560   0.087   0.135    0.134
#
#      MAPE  RMSE
# 21 23.054 0.140
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 22  0.817  0.109 -0.500   1.027   1.114   -0.560   0.071   0.150    0.134
#
#      MAPE  RMSE
# 22 24.499 0.136
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 23  0.817  0.108 -0.500   1.027   1.115   -0.560   0.066   0.156    0.136
#
#      MAPE  RMSE
# 23 24.925 0.134
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 24  0.817  0.108 -0.501   1.027   1.115   -0.561   0.062   0.159    0.138
#
#      MAPE  RMSE
# 24 25.203 0.133
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 25  0.817  0.108 -0.501   1.027   1.115   -0.561   0.059   0.157    0.140
#
#      MAPE  RMSE
# 25 25.437 0.133
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 26  0.817  0.108 -0.501   1.027   1.115   -0.561   0.055   0.150    0.142
#
#      MAPE  RMSE
# 26 25.964 0.135
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 27  0.817  0.108 -0.501   1.027   1.115   -0.561   0.047   0.139    0.144
#
#      MAPE  RMSE
# 27 27.043 0.139
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 28  0.817  0.108 -0.501   1.027   1.115   -0.561   0.034   0.121    0.144
#
#      MAPE  RMSE
# 28 28.933 0.145
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 29  0.817  0.108 -0.500   1.027   1.115   -0.561   0.021   0.105    0.142
#
#      MAPE  RMSE
# 29 30.767 0.150
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 30  0.817  0.109 -0.500   1.027   1.115   -0.561   0.014   0.096    0.140
#
#      MAPE  RMSE
# 30 31.855 0.153
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 31  0.817  0.109 -0.500   1.027   1.115   -0.561   0.010   0.093    0.139
#
#      MAPE  RMSE
# 31 32.378 0.154
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 32  0.817  0.109 -0.500   1.027   1.115   -0.561   0.006   0.093    0.139
#
#      MAPE  RMSE
# 32 32.834 0.155
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 33  0.817  0.109 -0.500   1.027   1.115   -0.561   0.003   0.096    0.139
#
#      MAPE  RMSE
# 33 33.130 0.154
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 34  0.817  0.109 -0.500   1.027   1.115   -0.561   0.001   0.102    0.139
#
#      MAPE  RMSE
# 34 33.131 0.153
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 35  0.817  0.109 -0.500   1.027   1.115   -0.561   0.001   0.106    0.139
#
#      MAPE  RMSE
# 35 33.069 0.151
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 36  0.817  0.109 -0.500   1.027   1.115   -0.561   0.001   0.109    0.140
#
#      MAPE  RMSE
# 36 33.031 0.150
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 37  0.817  0.109 -0.500   1.027   1.115   -0.561   0.000   0.111    0.140
#
#      MAPE  RMSE
# 37 33.008 0.150
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 38  0.817  0.109 -0.500   1.027   1.115   -0.561   0.000   0.110    0.140
#
#      MAPE  RMSE
# 38 33.033 0.150
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 39  0.817  0.109 -0.500   1.027   1.115   -0.561   0.000   0.109    0.139
#
#      MAPE  RMSE
# 39 33.079 0.151
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 40  0.817  0.109 -0.500   1.027   1.115   -0.561   0.000   0.106    0.139
#
#      MAPE  RMSE
# 40 33.127 0.151
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 41  0.817  0.109 -0.500   1.027   1.115   -0.561   0.000   0.105    0.139
#
#      MAPE  RMSE
# 41 33.175 0.152
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 42  0.817  0.109 -0.500   1.027   1.115   -0.561   0.000   0.104    0.139
#
#      MAPE  RMSE
# 42 33.195 0.152
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 43  0.817  0.109 -0.500   1.027   1.115   -0.561   0.000   0.104    0.139
#
#      MAPE  RMSE
# 43 33.199 0.152
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 44  0.817  0.109 -0.500   1.027   1.115   -0.561   0.000   0.104    0.139
#
#      MAPE  RMSE
# 44 33.198 0.152
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 45  0.817  0.109 -0.500   1.027   1.115   -0.561   0.000   0.104    0.139
#
#      MAPE  RMSE
# 45 33.194 0.152
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 46  0.817  0.109 -0.500   1.027   1.115   -0.561   0.000   0.106    0.140
#
#      MAPE  RMSE
# 46 33.151 0.151
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 47  0.817  0.109 -0.500   1.027   1.115   -0.561   0.000   0.106    0.140
#
#      MAPE  RMSE
# 47 33.142 0.151
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 48  0.817  0.109 -0.500   1.027   1.115   -0.561   0.000   0.106    0.139
#
#      MAPE  RMSE
# 48 33.140 0.151
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 49  0.817  0.109 -0.500   1.027   1.115   -0.561   0.000   0.106    0.139
#
#      MAPE  RMSE
# 49 33.140 0.151
# Optimization done, time elapsed: 0:40:44
#       c_0: array([0.59941084, 0.96298294, 0.59095403, 0.87086462, 0.6879298 ,
#        0.80193026, 0.57968879, 0.40834303, 0.98330794])
#       dgp: 'bigbatch'
#     dgp_i: 250
#     dgp_n: 1000
#  drawtype: 'pseudo'
#  duration: 2444.4603300094604
#       fun: 3386.512373378981
#  hess_inv: array([[ 6.91588691e-03,  1.03150003e-03,  3.92631093e-03,
#         -1.51689210e-03,  6.21595841e-04, -3.02754917e-03,
#         -4.07927578e-02,  1.16874771e-02,  4.02177312e-03],
#        [ 1.03150003e-03,  2.89969533e-03,  1.23394990e-03,
#         -4.47046106e-04,  3.94105523e-04,  3.95545497e-04,
#         -2.81452678e-03, -4.85698925e-04, -1.49266240e-04],
#        [ 3.92631093e-03,  1.23394990e-03,  6.36708850e-03,
#         -1.90402080e-03,  1.10192181e-04, -1.81579296e-03,
#         -2.02926766e-02,  7.86776278e-04,  3.39422549e-03],
#        [-1.51689210e-03, -4.47046106e-04, -1.90402080e-03,
#          8.88937768e-03, -1.61653632e-03,  1.25405471e-03,
#         -8.62649496e-03,  2.44840635e-03, -1.08003415e-03],
#        [ 6.21595841e-04,  3.94105523e-04,  1.10192181e-04,
#         -1.61653632e-03,  9.95862105e-03, -3.17163170e-04,
#          2.40429051e-02, -8.87019406e-03,  2.37365501e-03],
#        [-3.02754917e-03,  3.95545497e-04, -1.81579296e-03,
#          1.25405471e-03, -3.17163170e-04,  2.56441690e-03,
#          2.64890568e-02, -8.78703287e-03, -5.48301675e-03],
#        [-4.07927578e-02, -2.81452678e-03, -2.02926766e-02,
#         -8.62649496e-03,  2.40429051e-02,  2.64890568e-02,
#          1.63602980e+01, -8.76630639e+00, -4.53529731e-01],
#        [ 1.16874771e-02, -4.85698925e-04,  7.86776278e-04,
#          2.44840635e-03, -8.87019406e-03, -8.78703287e-03,
#         -8.76630639e+00,  4.77731322e+00,  1.39190689e-01],
#        [ 4.02177312e-03, -1.49266240e-04,  3.39422549e-03,
#         -1.08003415e-03,  2.37365501e-03, -5.48301675e-03,
#         -4.53529731e-01,  1.39190689e-01,  1.97691552e-01]])
#       jac: array([ 2.44140625e-04, -2.74658203e-04, -5.79833984e-04,  9.15527344e-05,
#        -1.83105469e-04,  5.49316406e-04,  9.15527344e-05,  4.27246094e-04,
#         8.23974609e-04])
#   message: 'Desired error not necessarily achieved due to precision loss.'
#    method: 'BFGS'
#   n_draws: 500
#      nfev: 782
#       nit: 50
#      njev: 71
#    status: 2
#   success: False
#    true_c: [0.8, 0.2, -0.5, 0.9, 1.1, -0.5, 0.1, 0.5, 0.25]
#         x: array([ 8.17034286e-01,  1.08554305e-01, -4.99845905e-01,  1.02691482e+00,
#         1.11459665e+00, -5.60760713e-01,  1.27408737e-04,  1.06393148e-01,
#         1.39492265e-01])
# Saving run 1 of 250
#
# Fitting model 2 of 250
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 0  0.864  0.450 -0.377   0.163   0.590    0.196   1.699   1.735    1.177
#
#      MAPE  RMSE
# 0 293.605 0.837
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 1  0.737  0.253 -0.531   0.376   0.738   -0.418   1.560   1.653    0.765
#
#      MAPE  RMSE
# 1 227.214 0.679
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 2  1.198 -0.052 -0.679   1.068   1.259   -0.578   0.926   1.136    0.117
#
#      MAPE  RMSE
# 2 140.820 0.397
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 3  1.200  0.216 -0.703   1.220   1.384   -0.656   0.781   0.992    0.077
#
#      MAPE  RMSE
# 3 115.538 0.357
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 4  0.957  0.182 -0.914   1.212   1.483   -0.526   0.649   0.855    0.073
#
#     MAPE  RMSE
# 4 97.424 0.316
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 5  0.991  0.042 -0.805   1.168   1.368   -0.609   0.326   0.537    0.092
#
#     MAPE  RMSE
# 5 59.648 0.208
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 6  0.984  0.052 -0.736   1.159   1.340   -0.587   0.218   0.642    0.103
#
#     MAPE  RMSE
# 6 46.386 0.182
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 7  0.997  0.058 -0.702   0.983   1.363   -0.601   0.187   0.676    0.104
#
#     MAPE  RMSE
# 7 41.116 0.165
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 8  1.004  0.066 -0.650   0.984   1.454   -0.595   0.170   0.636    0.114
#
#     MAPE  RMSE
# 8 37.227 0.172
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 9  0.976  0.079 -0.607   0.982   1.377   -0.572   0.145   0.577    0.124
#
#     MAPE  RMSE
# 9 29.303 0.137
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 10  0.895  0.083 -0.527   1.002   1.373   -0.533   0.068   0.822    0.167
#
#      MAPE  RMSE
# 10 27.524 0.157
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 11  0.806  0.148 -0.355   1.012   1.207   -0.451   0.054   0.362    0.287
#
#      MAPE  RMSE
# 11 19.519 0.090
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 12  0.784  0.169 -0.454   1.033   1.267   -0.446   0.076   0.451    0.244
#
#      MAPE  RMSE
# 12 11.558 0.078
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 13  0.796  0.168 -0.463   1.037   1.305   -0.458   0.062   0.604    0.282
#
#      MAPE  RMSE
# 13 15.264 0.093
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 14  0.796  0.172 -0.468   1.034   1.275   -0.464   0.064   0.617    0.308
#
#      MAPE  RMSE
# 14 15.752 0.088
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 15  0.798  0.173 -0.472   1.032   1.268   -0.468   0.071   0.584    0.304
#
#      MAPE  RMSE
# 15 13.759 0.081
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 16  0.799  0.172 -0.475   1.032   1.275   -0.470   0.076   0.576    0.306
#
#      MAPE  RMSE
# 16 13.059 0.082
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 17  0.799  0.172 -0.476   1.032   1.278   -0.471   0.078   0.573    0.306
#
#      MAPE  RMSE
# 17 12.702 0.082
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 18  0.800  0.173 -0.476   1.033   1.280   -0.471   0.084   0.570    0.307
#
#      MAPE  RMSE
# 18 12.038 0.082
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 19  0.804  0.173 -0.481   1.034   1.296   -0.474   0.156   0.551    0.309
#
#      MAPE  RMSE
# 19 16.147 0.087
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 20  0.805  0.174 -0.483   1.035   1.302   -0.475   0.206   0.543    0.310
#
#      MAPE  RMSE
# 20 21.615 0.093
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 21  0.805  0.173 -0.483   1.036   1.301   -0.475   0.242   0.545    0.309
#
#      MAPE  RMSE
# 21 25.589 0.098
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 22  0.804  0.173 -0.481   1.035   1.295   -0.473   0.248   0.555    0.308
#
#      MAPE  RMSE
# 22 26.430 0.098
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 23  0.799  0.172 -0.477   1.033   1.279   -0.470   0.242   0.580    0.306
#
#      MAPE  RMSE
# 23 26.256 0.095
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 24  0.799  0.172 -0.477   1.033   1.279   -0.470   0.251   0.577    0.306
#
#      MAPE  RMSE
# 24 27.219 0.097
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 25  0.799  0.172 -0.477   1.033   1.279   -0.470   0.248   0.577    0.306
#
#      MAPE  RMSE
# 25 26.793 0.096
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 26  0.799  0.172 -0.477   1.033   1.279   -0.470   0.248   0.577    0.306
#
#      MAPE  RMSE
# 26 26.824 0.096
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 27  0.799  0.172 -0.477   1.033   1.279   -0.470   0.248   0.577    0.306
#
#      MAPE  RMSE
# 27 26.821 0.096
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 28  0.799  0.172 -0.477   1.033   1.279   -0.470   0.248   0.577    0.306
#
#      MAPE  RMSE
# 28 26.821 0.096
# Optimization done, time elapsed: 0:25:31
#       c_0: array([0.39670921, 0.39041906, 0.41033046, 0.06711224, 0.52765961,
#        0.59560029, 0.58392975, 0.58631065, 0.20075806])
#       dgp: 'bigbatch'
#     dgp_i: 251
#     dgp_n: 1000
#  drawtype: 'pseudo'
#  duration: 1530.8506948947906
#       fun: 3412.489669525852
#  hess_inv: array([[ 8.44370925e-03,  1.87722014e-03,  5.02850965e-03,
#         -1.29979268e-03, -4.27170917e-04, -3.78223302e-03,
#          1.89148913e-03, -1.47516094e-03, -1.41343015e-03],
#        [ 1.87722014e-03,  3.28469048e-03,  1.71903159e-03,
#         -2.56265668e-04, -1.03251776e-04,  4.99077804e-05,
#          3.32347803e-03,  2.38675238e-04, -4.70435744e-04],
#        [ 5.02850965e-03,  1.71903159e-03,  7.19423488e-03,
#         -1.77194855e-03, -1.07949660e-03, -2.20612900e-03,
#          1.83522765e-03, -2.35682851e-03, -1.11169182e-03],
#        [-1.29979268e-03, -2.56265668e-04, -1.77194855e-03,
#          8.39866439e-03, -7.05548448e-04,  1.07933531e-03,
#         -1.07597389e-02,  1.18971924e-03,  1.15280769e-03],
#        [-4.27170917e-04, -1.03251776e-04, -1.07949660e-03,
#         -7.05548448e-04,  1.14805513e-02,  2.86008155e-04,
#          8.76702097e-03, -4.22756486e-04,  6.25139167e-04],
#        [-3.78223302e-03,  4.99077804e-05, -2.20612900e-03,
#          1.07933531e-03,  2.86008155e-04,  3.14626300e-03,
#         -3.89427425e-04,  1.35412924e-03,  5.36594750e-04],
#        [ 1.89148913e-03,  3.32347803e-03,  1.83522765e-03,
#         -1.07597389e-02,  8.76702097e-03, -3.89427425e-04,
#          4.43982712e-02,  3.27984921e-02,  1.49264315e-02],
#        [-1.47516094e-03,  2.38675238e-04, -2.35682851e-03,
#          1.18971924e-03, -4.22756486e-04,  1.35412924e-03,
#          3.27984921e-02,  1.00933234e-01,  1.17530290e-03],
#        [-1.41343015e-03, -4.70435744e-04, -1.11169182e-03,
#          1.15280769e-03,  6.25139167e-04,  5.36594750e-04,
#          1.49264315e-02,  1.17530290e-03,  2.41881255e-02]])
#       jac: array([ 1.22070312e-04, -3.66210938e-04,  1.52587891e-04, -1.83105469e-04,
#        -9.15527344e-05,  1.19018555e-03,  0.00000000e+00,  0.00000000e+00,
#         1.83105469e-04])
#   message: 'Desired error not necessarily achieved due to precision loss.'
#    method: 'BFGS'
#   n_draws: 500
#      nfev: 485
#       nit: 29
#      njev: 44
#    status: 2
#   success: False
#    true_c: [0.8, 0.2, -0.5, 0.9, 1.1, -0.5, 0.1, 0.5, 0.25]
#         x: array([ 0.79912757,  0.17172994, -0.47667596,  1.03305428,  1.27876547,
#        -0.47017379,  0.24773792,  0.57726852,  0.30573074])
# Saving run 2 of 250
#
# Fitting model 3 of 250
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 0  1.181  0.499 -0.113   0.430   0.399   -0.159   1.384   1.734    1.129
#
#      MAPE  RMSE
# 0 260.129 0.757
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 1  0.954  0.497 -0.263   0.509   0.482   -0.459   1.309   1.716    0.748
#
#      MAPE  RMSE
# 1 219.340 0.658
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 2  0.957  0.158 -0.373   0.622   0.590   -0.484   1.199   1.626    0.457
#
#      MAPE  RMSE
# 2 172.609 0.568
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 3  0.955  0.273 -0.313   0.869   0.799   -0.376   0.947   1.240    0.398
#
#      MAPE  RMSE
# 3 133.708 0.403
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 4  1.011  0.201 -0.325   1.158   1.105   -0.525   0.665   0.808    0.425
#
#     MAPE  RMSE
# 4 88.076 0.255
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 5  0.864  0.153 -0.443   0.975   1.232   -0.462   0.519   0.607    0.434
#
#     MAPE  RMSE
# 5 64.940 0.168
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 6  0.865  0.163 -0.429   0.886   1.046   -0.493   0.428   0.517    0.407
#
#     MAPE  RMSE
# 6 49.161 0.127
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 7  0.801  0.175 -0.466   0.924   1.048   -0.469   0.371   0.647    0.395
#
#     MAPE  RMSE
# 7 43.518 0.116
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 8  0.859  0.212 -0.404   0.844   1.128   -0.507   0.348   0.723    0.374
#
#     MAPE  RMSE
# 8 42.745 0.126
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 9  0.832  0.214 -0.424   0.855   1.113   -0.492   0.301   0.873    0.370
#
#     MAPE  RMSE
# 9 39.720 0.150
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 10  0.772  0.235 -0.477   0.909   1.099   -0.471   0.404   0.828    0.337
#
#      MAPE  RMSE
# 10 48.524 0.153
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 11  0.657  0.247 -0.570   0.924   1.076   -0.396   0.397   1.066    0.301
#
#      MAPE  RMSE
# 11 56.793 0.224
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 12  0.667  0.247 -0.565   0.934   1.081   -0.403   0.525   0.943    0.290
#
#      MAPE  RMSE
# 12 67.550 0.214
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 13  0.681  0.244 -0.555   0.927   1.079   -0.412   0.508   0.982    0.287
#
#      MAPE  RMSE
# 13 65.492 0.218
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 14  0.682  0.243 -0.555   0.922   1.076   -0.410   0.519   0.990    0.283
#
#      MAPE  RMSE
# 14 66.696 0.222
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 15  0.682  0.243 -0.555   0.921   1.075   -0.410   0.522   0.989    0.282
#
#      MAPE  RMSE
# 15 66.927 0.223
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 16  0.682  0.243 -0.555   0.921   1.074   -0.410   0.521   0.988    0.282
#
#      MAPE  RMSE
# 16 66.847 0.222
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 17  0.682  0.243 -0.555   0.921   1.074   -0.410   0.521   0.988    0.282
#
#      MAPE  RMSE
# 17 66.848 0.222
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 18  0.682  0.243 -0.555   0.921   1.074   -0.410   0.521   0.988    0.282
#
#      MAPE  RMSE
# 18 66.819 0.222
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 19  0.682  0.243 -0.555   0.921   1.074   -0.410   0.521   0.988    0.282
#
#      MAPE  RMSE
# 19 66.823 0.222
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 20  0.682  0.243 -0.555   0.921   1.074   -0.410   0.521   0.988    0.282
#
#      MAPE  RMSE
# 20 66.824 0.222
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 21  0.682  0.243 -0.555   0.921   1.074   -0.410   0.521   0.988    0.282
#
#      MAPE  RMSE
# 21 66.824 0.222
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 22  0.682  0.243 -0.555   0.921   1.074   -0.410   0.521   0.988    0.282
#
#      MAPE  RMSE
# 22 66.824 0.222
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 23  0.682  0.243 -0.555   0.921   1.074   -0.410   0.521   0.988    0.282
#
#      MAPE  RMSE
# 23 66.824 0.222
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 24  0.682  0.243 -0.555   0.921   1.074   -0.410   0.521   0.988    0.282
#
#      MAPE  RMSE
# 24 66.824 0.222
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 25  0.682  0.243 -0.555   0.921   1.074   -0.410   0.521   0.988    0.282
#
#      MAPE  RMSE
# 25 66.824 0.222
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 26  0.682  0.243 -0.555   0.921   1.074   -0.410   0.521   0.988    0.282
#
#      MAPE  RMSE
# 26 66.824 0.222
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 27  0.682  0.243 -0.555   0.921   1.074   -0.410   0.521   0.988    0.282
#
#      MAPE  RMSE
# 27 66.824 0.222
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 28  0.682  0.243 -0.555   0.921   1.074   -0.410   0.521   0.988    0.282
#
#      MAPE  RMSE
# 28 66.824 0.222
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 29  0.682  0.243 -0.555   0.921   1.074   -0.410   0.521   0.988    0.282
#
#      MAPE  RMSE
# 29 66.824 0.222
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 30  0.682  0.243 -0.555   0.921   1.074   -0.410   0.521   0.988    0.282
#
#      MAPE  RMSE
# 30 66.824 0.222
# Optimization done, time elapsed: 0:24:03
#       c_0: array([0.8524326 , 0.198425  , 0.69249615, 0.38963742, 0.34324815,
#        0.02311042, 0.3822491 , 0.55260513, 0.4845315 ])
#       dgp: 'bigbatch'
#     dgp_i: 252
#     dgp_n: 1000
#  drawtype: 'pseudo'
#  duration: 1443.0080873966217
#       fun: 3437.579338883899
#  hess_inv: array([[ 2.11785300e-03, -5.10577159e-04,  6.00949450e-04,
#          2.06214963e-04,  1.03585885e-03, -1.39277403e-03,
#         -1.83103656e-03,  2.76938700e-04,  4.36198602e-04],
#        [-5.10577159e-04,  1.30900227e-03,  4.50291662e-04,
#         -6.16586975e-04, -9.02445294e-04,  2.72020587e-04,
#          2.42598729e-04,  8.21592748e-05, -3.99644431e-04],
#        [ 6.00949450e-04,  4.50291662e-04,  1.66929229e-03,
#         -9.45205875e-04,  1.09797447e-03, -2.58682077e-05,
#         -7.89289738e-04, -1.07954302e-03,  6.20809768e-04],
#        [ 2.06214963e-04, -6.16586975e-04, -9.45205875e-04,
#          1.10563669e-03, -2.62374772e-04, -3.60052929e-04,
#         -4.87976668e-05,  8.76504388e-04, -8.99590714e-05],
#        [ 1.03585885e-03, -9.02445294e-04,  1.09797447e-03,
#         -2.62374772e-04,  3.17001853e-03, -2.90781397e-04,
#         -1.48092183e-03, -2.65718681e-03,  1.75257411e-03],
#        [-1.39277403e-03,  2.72020587e-04, -2.58682077e-05,
#         -3.60052929e-04, -2.90781397e-04,  1.40639904e-03,
#          9.62131590e-04, -7.44711465e-04,  1.78346265e-04],
#        [-1.83103656e-03,  2.42598729e-04, -7.89289738e-04,
#         -4.87976668e-05, -1.48092183e-03,  9.62131590e-04,
#          2.26203483e-03,  7.18573313e-04, -8.67473089e-04],
#        [ 2.76938700e-04,  8.21592748e-05, -1.07954302e-03,
#          8.76504388e-04, -2.65718681e-03, -7.44711465e-04,
#          7.18573313e-04,  3.77278875e-03, -1.67780241e-03],
#        [ 4.36198602e-04, -3.99644431e-04,  6.20809768e-04,
#         -8.99590714e-05,  1.75257411e-03,  1.78346265e-04,
#         -8.67473089e-04, -1.67780241e-03,  1.46085934e-03]])
#       jac: array([ 3.05175781e-05, -2.13623047e-04,  6.10351562e-05,  6.10351562e-05,
#        -1.22070312e-04,  1.83105469e-04, -9.15527344e-05, -3.05175781e-05,
#        -1.52587891e-04])
#   message: 'Desired error not necessarily achieved due to precision loss.'
#    method: 'BFGS'
#   n_draws: 500
#      nfev: 441
#       nit: 31
#      njev: 40
#    status: 2
#   success: False
#    true_c: [0.8, 0.2, -0.5, 0.9, 1.1, -0.5, 0.1, 0.5, 0.25]
#         x: array([ 0.6821864 ,  0.24323826, -0.55510324,  0.92127244,  1.07427594,
#        -0.40962002,  0.52092577,  0.98835113,  0.28169144])
# Saving run 3 of 250
#
# Fitting model 4 of 250
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 0  1.267  0.467 -0.137   0.678   0.536    0.168   1.745   1.745    1.237
#
#      MAPE  RMSE
# 0 307.054 0.848
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 1  0.945  0.374 -0.455   0.744   0.663   -0.539   1.396   1.694    0.743
#
#      MAPE  RMSE
# 1 212.237 0.634
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 2  0.845  0.056 -0.434   0.815   0.773   -0.681   1.160   1.598    0.407
#
#      MAPE  RMSE
# 2 167.611 0.530
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 3  0.757  0.246 -0.432   0.873   0.899   -0.582   0.924   1.457    0.327
#
#      MAPE  RMSE
# 3 125.090 0.429
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 4  0.622  0.158 -0.534   0.957   1.197   -0.437   0.538   1.162    0.348
#
#     MAPE  RMSE
# 4 76.354 0.277
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 5  0.783  0.176 -0.410   0.961   1.245   -0.545   0.410   0.962    0.360
#
#     MAPE  RMSE
# 5 56.429 0.199
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 6  0.800  0.177 -0.388   0.839   1.147   -0.556   0.356   0.893    0.358
#
#     MAPE  RMSE
# 6 48.213 0.168
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 7  0.800  0.175 -0.389   0.887   1.052   -0.553   0.337   0.877    0.357
#
#     MAPE  RMSE
# 7 45.135 0.159
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 8  0.817  0.182 -0.377   0.886   1.055   -0.550   0.333   0.895    0.350
#
#     MAPE  RMSE
# 8 44.761 0.164
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 9  0.808  0.188 -0.395   0.888   1.058   -0.534   0.358   0.752    0.333
#
#     MAPE  RMSE
# 9 42.409 0.130
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 10  0.841  0.191 -0.406   0.891   1.070   -0.536   0.325   0.785    0.310
#
#      MAPE  RMSE
# 10 38.371 0.128
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 11  0.888  0.196 -0.421   0.894   1.091   -0.536   0.259   0.828    0.263
#
#      MAPE  RMSE
# 11 29.667 0.128
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 12  0.890  0.196 -0.422   0.894   1.093   -0.539   0.231   0.824    0.250
#
#      MAPE  RMSE
# 12 25.962 0.124
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 13  0.886  0.195 -0.420   0.892   1.092   -0.537   0.201   0.819    0.240
#
#      MAPE  RMSE
# 13 23.001 0.119
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 14  0.883  0.195 -0.420   0.892   1.092   -0.537   0.179   0.817    0.237
#
#      MAPE  RMSE
# 14 20.622 0.116
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 15  0.881  0.195 -0.419   0.892   1.093   -0.535   0.146   0.814    0.236
#
#      MAPE  RMSE
# 15 16.805 0.113
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 16  0.880  0.196 -0.419   0.893   1.094   -0.535   0.111   0.810    0.239
#
#      MAPE  RMSE
# 16 12.649 0.111
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 17  0.881  0.196 -0.419   0.893   1.095   -0.535   0.083   0.808    0.243
#
#      MAPE  RMSE
# 17 13.048 0.110
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 18  0.882  0.196 -0.420   0.893   1.096   -0.535   0.069   0.808    0.245
#
#      MAPE  RMSE
# 18 14.566 0.111
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 19  0.882  0.196 -0.420   0.893   1.096   -0.535   0.058   0.807    0.246
#
#      MAPE  RMSE
# 19 15.697 0.111
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 20  0.882  0.196 -0.420   0.893   1.096   -0.535   0.048   0.807    0.245
#
#      MAPE  RMSE
# 20 16.872 0.111
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 21  0.882  0.196 -0.420   0.893   1.095   -0.535   0.041   0.807    0.244
#
#      MAPE  RMSE
# 21 17.671 0.112
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 22  0.882  0.196 -0.420   0.893   1.095   -0.535   0.038   0.807    0.244
#
#      MAPE  RMSE
# 22 18.006 0.112
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 23  0.882  0.196 -0.420   0.893   1.095   -0.535   0.037   0.807    0.244
#
#      MAPE  RMSE
# 23 18.093 0.112
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 24  0.882  0.196 -0.420   0.893   1.095   -0.535   0.037   0.807    0.244
#
#      MAPE  RMSE
# 24 18.103 0.112
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 25  0.882  0.196 -0.420   0.893   1.095   -0.535   0.037   0.807    0.244
#
#      MAPE  RMSE
# 25 18.140 0.112
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 26  0.882  0.196 -0.420   0.893   1.095   -0.535   0.037   0.807    0.244
#
#      MAPE  RMSE
# 26 18.144 0.112
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 27  0.882  0.196 -0.420   0.893   1.095   -0.535   0.037   0.807    0.244
#
#      MAPE  RMSE
# 27 18.145 0.112
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 28  0.882  0.196 -0.420   0.893   1.095   -0.535   0.037   0.807    0.244
#
#      MAPE  RMSE
# 28 18.147 0.112
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 29  0.882  0.196 -0.420   0.893   1.095   -0.535   0.037   0.807    0.244
#
#      MAPE  RMSE
# 29 18.146 0.112
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 30  0.882  0.196 -0.420   0.893   1.095   -0.535   0.037   0.807    0.244
#
#      MAPE  RMSE
# 30 18.144 0.112
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 31  0.882  0.196 -0.420   0.893   1.095   -0.535   0.037   0.807    0.244
#
#      MAPE  RMSE
# 31 18.139 0.112
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 32  0.882  0.196 -0.420   0.893   1.095   -0.535   0.037   0.807    0.244
#
#      MAPE  RMSE
# 32 18.132 0.112
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 33  0.882  0.196 -0.420   0.893   1.095   -0.535   0.037   0.807    0.244
#
#      MAPE  RMSE
# 33 18.132 0.112
# Optimization done, time elapsed: 0:32:49
#       c_0: array([0.84317752, 0.49311278, 0.6460969 , 0.66278314, 0.48113358,
#        0.38013998, 0.681948  , 0.58012807, 0.61571524])
#       dgp: 'bigbatch'
#     dgp_i: 253
#     dgp_n: 1000
#  drawtype: 'pseudo'
#  duration: 1968.6919932365417
#       fun: 3423.11518025318
#  hess_inv: array([[ 4.51359332e-03,  4.48172780e-04,  2.26631012e-03,
#         -2.09404645e-03,  1.13525716e-03, -2.27379946e-03,
#          1.90721010e-02, -1.17655977e-04, -2.86907072e-04],
#        [ 4.48172780e-04,  2.25953979e-03,  5.81486786e-04,
#         -5.80568630e-04,  6.92988634e-04,  4.13806483e-04,
#          1.08840658e-02, -7.18655015e-04, -1.16993507e-03],
#        [ 2.26631012e-03,  5.81486786e-04,  4.69292473e-03,
#         -2.77265709e-03,  9.72167104e-04, -1.38799104e-03,
#          3.67905334e-02, -2.47753486e-03, -1.05008869e-03],
#        [-2.09404645e-03, -5.80568630e-04, -2.77265709e-03,
#          8.36490841e-03, -4.28669381e-04,  1.12180070e-03,
#         -2.74334913e-02, -2.68397378e-04,  2.48041130e-03],
#        [ 1.13525716e-03,  6.92988634e-04,  9.72167104e-04,
#         -4.28669381e-04,  1.19761063e-02, -4.43974619e-05,
#         -1.29963465e-02,  2.54443171e-03,  4.13266700e-03],
#        [-2.27379946e-03,  4.13806483e-04, -1.38799104e-03,
#          1.12180070e-03, -4.43974619e-05,  2.30166672e-03,
#         -9.06175945e-03, -7.61202253e-04,  1.58690535e-04],
#        [ 1.90721010e-02,  1.08840658e-02,  3.67905334e-02,
#         -2.74334913e-02, -1.29963465e-02, -9.06175945e-03,
#          9.23925838e-01, -2.03888730e-01, -4.50624443e-02],
#        [-1.17655977e-04, -7.18655015e-04, -2.47753486e-03,
#         -2.68397378e-04,  2.54443171e-03, -7.61202253e-04,
#         -2.03888730e-01,  6.25530607e-02,  2.48310458e-03],
#        [-2.86907072e-04, -1.16993507e-03, -1.05008869e-03,
#          2.48041130e-03,  4.13266700e-03,  1.58690535e-04,
#         -4.50624443e-02,  2.48310458e-03,  1.70795705e-02]])
#       jac: array([-2.44140625e-04, -6.71386719e-04,  2.13623047e-04,  2.13623047e-04,
#        -1.15966797e-03,  7.62939453e-04,  3.05175781e-05, -3.66210938e-04,
#        -6.10351562e-04])
#   message: 'Desired error not necessarily achieved due to precision loss.'
#    method: 'BFGS'
#   n_draws: 500
#      nfev: 617
#       nit: 34
#      njev: 56
#    status: 2
#   success: False
#    true_c: [0.8, 0.2, -0.5, 0.9, 1.1, -0.5, 0.1, 0.5, 0.25]
#         x: array([ 0.88179106,  0.19589968, -0.4195145 ,  0.89316583,  1.09543511,
#        -0.53476579,  0.03707864,  0.80723986,  0.24419589])
# Saving run 4 of 250
#
# Fitting model 5 of 250
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 0  0.782  0.478  0.038   0.891   0.257    0.449   1.046   2.256    1.390
#
#      MAPE  RMSE
# 0 252.155 0.898
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 1  0.550  0.118 -0.236   0.951   0.439   -0.377   0.928   2.056    0.761
#
#      MAPE  RMSE
# 1 173.253 0.663
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 2  0.532  0.205 -0.250   0.966   0.534   -0.504   0.869   1.914    0.520
#
#      MAPE  RMSE
# 2 145.040 0.589
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 3  0.612  0.041 -0.222   0.971   0.662   -0.451   0.798   1.733    0.384
#
#      MAPE  RMSE
# 3 134.931 0.512
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 4  0.684  0.041 -0.188   0.888   1.305   -0.516   0.530   0.956    0.394
#
#     MAPE  RMSE
# 4 84.250 0.256
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 5  0.562  0.034 -0.291   0.848   1.274   -0.437   0.470   0.831    0.387
#
#     MAPE  RMSE
# 5 75.548 0.219
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 6  0.572  0.037 -0.306   0.977   1.103   -0.437   0.389   0.677    0.385
#
#     MAPE  RMSE
# 6 60.948 0.170
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 7  0.655  0.048 -0.264   0.820   0.990   -0.492   0.335   0.640    0.377
#
#     MAPE  RMSE
# 7 52.850 0.153
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 8  0.672  0.065 -0.274   0.824   1.016   -0.491   0.306   0.667    0.372
#
#     MAPE  RMSE
# 8 48.282 0.143
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 9  0.686  0.072 -0.321   0.837   1.069   -0.500   0.417   0.517    0.349
#
#     MAPE  RMSE
# 9 53.743 0.140
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 10  0.716  0.100 -0.407   0.867   1.170   -0.507   0.264   0.579    0.319
#
#      MAPE  RMSE
# 10 33.086 0.088
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 11  0.791  0.177 -0.474   0.901   1.287   -0.478   0.265   0.473    0.269
#
#      MAPE  RMSE
# 11 24.187 0.085
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 12  0.762  0.140 -0.521   0.904   1.294   -0.515   0.230   0.533    0.259
#
#      MAPE  RMSE
# 12 22.220 0.083
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 13  0.769  0.146 -0.502   0.900   1.275   -0.501   0.228   0.552    0.257
#
#      MAPE  RMSE
# 13 20.939 0.077
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 14  0.771  0.148 -0.496   0.899   1.276   -0.500   0.223   0.572    0.252
#
#      MAPE  RMSE
# 14 20.515 0.078
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 15  0.772  0.149 -0.494   0.898   1.279   -0.500   0.219   0.590    0.245
#
#      MAPE  RMSE
# 15 20.620 0.080
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 16  0.772  0.149 -0.494   0.898   1.279   -0.500   0.220   0.586    0.243
#
#      MAPE  RMSE
# 16 20.765 0.080
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 17  0.771  0.149 -0.494   0.898   1.278   -0.500   0.222   0.582    0.242
#
#      MAPE  RMSE
# 17 20.912 0.079
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 18  0.771  0.149 -0.494   0.898   1.277   -0.500   0.223   0.581    0.242
#
#      MAPE  RMSE
# 18 20.981 0.079
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 19  0.771  0.149 -0.494   0.898   1.277   -0.500   0.224   0.580    0.242
#
#      MAPE  RMSE
# 19 21.068 0.079
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 20  0.771  0.149 -0.494   0.898   1.277   -0.500   0.225   0.580    0.242
#
#      MAPE  RMSE
# 20 21.226 0.080
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 21  0.771  0.149 -0.494   0.898   1.277   -0.500   0.226   0.581    0.242
#
#      MAPE  RMSE
# 21 21.338 0.080
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 22  0.771  0.149 -0.494   0.898   1.277   -0.500   0.226   0.581    0.242
#
#      MAPE  RMSE
# 22 21.395 0.080
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 23  0.771  0.149 -0.494   0.898   1.277   -0.500   0.226   0.581    0.242
#
#      MAPE  RMSE
# 23 21.380 0.080
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 24  0.771  0.149 -0.494   0.898   1.277   -0.500   0.226   0.581    0.242
#
#      MAPE  RMSE
# 24 21.379 0.080
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 25  0.771  0.149 -0.494   0.898   1.277   -0.500   0.226   0.581    0.242
#
#      MAPE  RMSE
# 25 21.379 0.080
# Optimization done, time elapsed: 0:24:07
#       c_0: array([0.24706201, 0.44921901, 0.86247946, 0.90241661, 0.21654768,
#        0.63405588, 0.06533991, 0.82749047, 0.4621759 ])
#       dgp: 'bigbatch'
#     dgp_i: 254
#     dgp_n: 1000
#  drawtype: 'pseudo'
#  duration: 1447.1280660629272
#       fun: 3415.778933321721
#  hess_inv: array([[ 1.62276156e-02,  9.38710737e-03,  1.60235015e-02,
#          6.38388635e-03, -4.08267564e-03, -5.74884320e-03,
#          2.70772816e-01,  1.44586954e-02, -2.58382792e-02],
#        [ 9.38710737e-03,  1.01136398e-02,  1.15016323e-02,
#          6.19744584e-03, -3.45360050e-03, -2.17800177e-03,
#          2.12743523e-01,  1.50449493e-02, -2.15949109e-02],
#        [ 1.60235015e-02,  1.15016323e-02,  2.16233627e-02,
#          7.62930254e-03, -6.02828503e-03, -5.54825609e-03,
#          3.13546424e-01,  1.80847812e-02, -3.14381065e-02],
#        [ 6.38388635e-03,  6.19744584e-03,  7.62930254e-03,
#          1.49494204e-02, -4.19932702e-03, -1.14680409e-03,
#          1.99112034e-01,  1.60651501e-02, -1.90272449e-02],
#        [-4.08267564e-03, -3.45360050e-03, -6.02828503e-03,
#         -4.19932702e-03,  1.44418230e-02,  1.35239881e-03,
#         -7.68609424e-02, -5.81107478e-03,  1.18293283e-02],
#        [-5.74884320e-03, -2.17800177e-03, -5.54825609e-03,
#         -1.14680409e-03,  1.35239881e-03,  3.28969868e-03,
#         -8.24124799e-02, -4.81143943e-03,  7.28447316e-03],
#        [ 2.70772816e-01,  2.12743523e-01,  3.13546424e-01,
#          1.99112034e-01, -7.68609424e-02, -8.24124799e-02,
#          6.64666181e+00,  6.79456260e-01, -6.92304165e-01],
#        [ 1.44586954e-02,  1.50449493e-02,  1.80847812e-02,
#          1.60651501e-02, -5.81107478e-03, -4.81143943e-03,
#          6.79456260e-01,  1.74063924e-01, -4.52663958e-02],
#        [-2.58382792e-02, -2.15949109e-02, -3.14381065e-02,
#         -1.90272449e-02,  1.18293283e-02,  7.28447316e-03,
#         -6.92304165e-01, -4.52663958e-02,  1.05184619e-01]])
#       jac: array([ 2.74658203e-04, -1.22070312e-04, -2.44140625e-04, -3.05175781e-05,
#         2.13623047e-04, -6.10351562e-05, -9.15527344e-05,  9.15527344e-05,
#        -6.10351562e-05])
#   message: 'Desired error not necessarily achieved due to precision loss.'
#    method: 'BFGS'
#   n_draws: 500
#      nfev: 463
#       nit: 26
#      njev: 42
#    status: 2
#   success: False
#    true_c: [0.8, 0.2, -0.5, 0.9, 1.1, -0.5, 0.1, 0.5, 0.25]
#         x: array([ 0.77113328,  0.14865952, -0.49411633,  0.89794352,  1.27742103,
#        -0.50009754,  0.22615931,  0.5813826 ,  0.24214948])
# Saving run 5 of 250
#
# Fitting model 6 of 250
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 0  1.150  0.615  0.202   0.983   0.481   -0.027   1.747   1.077    1.716
#
#      MAPE  RMSE
# 0 322.251 0.856
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 1  0.774  0.295 -0.001   1.001   0.665   -0.398   1.443   1.034    0.586
#
#      MAPE  RMSE
# 1 200.658 0.545
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 2  0.738  0.344 -0.037   1.001   0.681   -0.461   1.403   1.014    0.570
#
#      MAPE  RMSE
# 2 195.975 0.526
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 3  0.663  0.408 -0.090   0.989   0.828   -0.350   1.067   0.821    0.552
#
#      MAPE  RMSE
# 3 157.736 0.403
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 4  0.619  0.158 -0.164   0.972   1.049   -0.485   0.680   0.512    0.640
#
#     MAPE  RMSE
# 4 96.070 0.268
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 5  0.666  0.167 -0.122   0.949   0.978   -0.511   0.654   0.437    0.613
#
#     MAPE  RMSE
# 5 93.247 0.263
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 6  0.604  0.157 -0.189   0.956   0.965   -0.475   0.767   0.324    0.586
#
#      MAPE  RMSE
# 6 107.597 0.288
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 7  0.665  0.192 -0.149   1.078   1.091   -0.489   0.851   0.276    0.547
#
#      MAPE  RMSE
# 7 114.341 0.312
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 8  0.684  0.213 -0.229   0.908   1.115   -0.488   0.653   0.343    0.442
#
#     MAPE  RMSE
# 8 82.370 0.225
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 9  0.632  0.198 -0.309   1.125   0.966   -0.458   0.560   0.371    0.420
#
#     MAPE  RMSE
# 9 73.247 0.209
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 10  0.629  0.216 -0.365   1.062   0.955   -0.416   0.533   0.350    0.372
#
#      MAPE  RMSE
# 10 68.495 0.191
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 11  0.622  0.235 -0.446   0.954   0.963   -0.394   0.441   0.312    0.282
#
#      MAPE  RMSE
# 11 53.570 0.157
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 12  0.630  0.236 -0.442   0.968   0.958   -0.385   0.415   0.280    0.259
#
#      MAPE  RMSE
# 12 50.758 0.156
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 13  0.630  0.235 -0.435   0.966   0.955   -0.394   0.385   0.259    0.241
#
#      MAPE  RMSE
# 13 47.776 0.153
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 14  0.629  0.234 -0.432   0.962   0.953   -0.389   0.374   0.253    0.238
#
#      MAPE  RMSE
# 14 47.008 0.152
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 15  0.630  0.235 -0.431   0.963   0.953   -0.389   0.367   0.250    0.238
#
#      MAPE  RMSE
# 15 46.356 0.152
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 16  0.629  0.235 -0.431   0.962   0.953   -0.389   0.354   0.245    0.239
#
#      MAPE  RMSE
# 16 44.933 0.150
# ...
# 3  1.045  0.471  0.041   1.021   0.818   -0.415   0.993   0.753    0.362
#
#      MAPE  RMSE
# 3 146.502 0.395
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 4  1.125  0.388  0.065   1.208   0.845   -0.543   0.834   0.603    0.380
#
#      MAPE  RMSE
# 4 124.528 0.363
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 5  0.975  0.355 -0.063   1.181   0.926   -0.471   0.655   0.384    0.372
#
#     MAPE  RMSE
# 5 96.303 0.277
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 6  0.964  0.355 -0.074   0.805   0.889   -0.575   0.545   0.149    0.299
#
#     MAPE  RMSE
# 6 84.767 0.262
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 7  0.924  0.344 -0.128   0.875   1.061   -0.590   0.703   0.107    0.273
#
#     MAPE  RMSE
# 7 97.490 0.280
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 8  0.866  0.330 -0.186   0.953   0.951   -0.577   0.756   0.094    0.256
#
#      MAPE  RMSE
# 8 101.168 0.288
#    a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 9  0.788  0.259 -0.333   0.901   0.993   -0.544   0.660   0.051    0.246
#
#     MAPE  RMSE
# 9 81.594 0.249
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 10  0.712  0.177 -0.585   0.863   1.071   -0.491   0.483   0.017    0.214
#
#      MAPE  RMSE
# 10 60.209 0.211
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 11  0.727  0.180 -0.590   0.892   1.074   -0.496   0.431   0.015    0.203
#
#      MAPE  RMSE
# 11 54.227 0.200
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 12  0.738  0.181 -0.582   0.902   1.073   -0.499   0.355   0.012    0.185
#
#      MAPE  RMSE
# 12 46.142 0.188
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 13  0.738  0.181 -0.574   0.898   1.069   -0.497   0.308   0.010    0.173
#
#      MAPE  RMSE
# 13 41.399 0.182
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 14  0.736  0.180 -0.570   0.894   1.067   -0.496   0.282   0.009    0.166
#
#      MAPE  RMSE
# 14 38.870 0.180
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 15  0.736  0.180 -0.570   0.894   1.066   -0.495   0.271   0.009    0.163
#
#      MAPE  RMSE
# 15 37.844 0.179
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 16  0.737  0.180 -0.570   0.894   1.066   -0.496   0.266   0.009    0.162
#
#      MAPE  RMSE
# 16 37.335 0.179
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 17  0.737  0.180 -0.570   0.894   1.066   -0.496   0.261   0.009    0.162
#
#      MAPE  RMSE
# 17 36.787 0.178
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 18  0.737  0.180 -0.570   0.894   1.066   -0.496   0.254   0.009    0.163
#
#      MAPE  RMSE
# 18 35.966 0.177
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 19  0.737  0.180 -0.570   0.894   1.066   -0.496   0.249   0.009    0.164
#
#      MAPE  RMSE
# 19 35.335 0.177
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 20  0.736  0.180 -0.570   0.894   1.066   -0.496   0.249   0.009    0.165
#
#      MAPE  RMSE
# 20 35.250 0.177
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 21  0.736  0.180 -0.570   0.894   1.066   -0.496   0.250   0.009    0.165
#
#      MAPE  RMSE
# 21 35.333 0.177
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 22  0.736  0.180 -0.570   0.894   1.066   -0.496   0.250   0.009    0.166
#
#      MAPE  RMSE
# 22 35.419 0.177
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 23  0.736  0.180 -0.570   0.894   1.066   -0.496   0.251   0.009    0.166
#
#      MAPE  RMSE
# 23 35.517 0.177
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 24  0.736  0.180 -0.570   0.894   1.066   -0.496   0.252   0.010    0.166
#
#      MAPE  RMSE
# 24 35.628 0.177
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 25  0.736  0.180 -0.570   0.894   1.066   -0.496   0.258   0.011    0.166
#
#      MAPE  RMSE
# 25 36.228 0.177
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 26  0.733  0.180 -0.565   0.893   1.067   -0.494   0.380   0.675    0.172
#
#      MAPE  RMSE
# 26 42.525 0.118
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 27  0.867  0.367 -0.209   0.242   0.433   -0.044   2.333   1.101    1.171
#
#       MAPE  RMSE
# 27 343.990 0.907
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 28  0.726  0.322 -0.320   0.314   0.570   -0.401   1.949   1.138    0.774
#
#       MAPE  RMSE
# 28 269.573 0.729
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 29  0.808  0.102 -0.275   0.430   0.670   -0.385   1.645   1.107    0.524
#
#       MAPE  RMSE
# 29 220.672 0.607
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 30  1.045  0.471  0.041   1.021   0.818   -0.415   0.993   0.753    0.362
#
#       MAPE  RMSE
# 30 146.502 0.395
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 31  1.125  0.388  0.065   1.208   0.845   -0.543   0.834   0.603    0.380
#
#       MAPE  RMSE
# 31 124.528 0.363
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 32  0.975  0.355 -0.063   1.181   0.926   -0.471   0.655   0.384    0.372
#
#      MAPE  RMSE
# 32 96.303 0.277
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 33  0.964  0.355 -0.074   0.805   0.889   -0.575   0.545   0.149    0.299
#
#      MAPE  RMSE
# 33 84.767 0.262
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 34  0.924  0.344 -0.128   0.875   1.061   -0.590   0.703   0.107    0.273
#
#      MAPE  RMSE
# 34 97.490 0.280
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 35  0.866  0.330 -0.186   0.953   0.951   -0.577   0.756   0.094    0.256
#
#       MAPE  RMSE
# 35 101.168 0.288
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 36  0.788  0.259 -0.333   0.901   0.993   -0.544   0.660   0.051    0.246
#
#      MAPE  RMSE
# 36 81.594 0.249
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 37  0.712  0.177 -0.585   0.863   1.071   -0.491   0.483   0.017    0.214
#
#      MAPE  RMSE
# 37 60.209 0.211
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 38  0.727  0.180 -0.590   0.892   1.074   -0.496   0.431   0.015    0.203
#
#      MAPE  RMSE
# 38 54.227 0.200
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 39  0.738  0.181 -0.582   0.902   1.073   -0.499   0.355   0.012    0.185
#
#      MAPE  RMSE
# 39 46.142 0.188
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 40  0.738  0.181 -0.574   0.898   1.069   -0.497   0.308   0.010    0.173
#
#      MAPE  RMSE
# 40 41.399 0.182
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 41  0.736  0.180 -0.570   0.894   1.067   -0.496   0.282   0.009    0.166
#
#      MAPE  RMSE
# 41 38.870 0.180
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 42  0.736  0.180 -0.570   0.894   1.066   -0.495   0.271   0.009    0.163
#
#      MAPE  RMSE
# 42 37.844 0.179
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 43  0.737  0.180 -0.570   0.894   1.066   -0.496   0.266   0.009    0.162
#
#      MAPE  RMSE
# 43 37.335 0.179
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 44  0.737  0.180 -0.570   0.894   1.066   -0.496   0.261   0.009    0.162
#
#      MAPE  RMSE
# 44 36.787 0.178
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 45  0.737  0.180 -0.570   0.894   1.066   -0.496   0.254   0.009    0.163
#
#      MAPE  RMSE
# 45 35.966 0.177
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 46  0.737  0.180 -0.570   0.894   1.066   -0.496   0.249   0.009    0.164
#
#      MAPE  RMSE
# 46 35.335 0.177
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 47  0.736  0.180 -0.570   0.894   1.066   -0.496   0.249   0.009    0.165
#
#      MAPE  RMSE
# 47 35.250 0.177
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 48  0.736  0.180 -0.570   0.894   1.066   -0.496   0.250   0.009    0.165
#
#      MAPE  RMSE
# 48 35.333 0.177
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 49  0.736  0.180 -0.570   0.894   1.066   -0.496   0.250   0.009    0.166
#
#      MAPE  RMSE
# 49 35.419 0.177
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 50  0.736  0.180 -0.570   0.894   1.066   -0.496   0.251   0.009    0.166
#
#      MAPE  RMSE
# 50 35.517 0.177
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 51  0.736  0.180 -0.570   0.894   1.066   -0.496   0.252   0.010    0.166
#
#      MAPE  RMSE
# 51 35.628 0.177
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 52  0.736  0.180 -0.570   0.894   1.066   -0.496   0.258   0.011    0.166
#
#      MAPE  RMSE
# 52 36.228 0.177
#     a h41  a h32  a h28  m disp  m feat  m price  s disp  s feat  s price  \
# 53  0.733  0.180 -0.565   0.893   1.067   -0.494   0.380   0.675    0.172
#
#      MAPE  RMSE
# 53 42.525 0.118
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\Code\mixedlogit\src\optimize.py in mixedlogit(data, drawtype, n_draws, true_c, dgp, dgp_i, dgp_n, c_0, method, verbose)
#     112         try:
# --> 113             res =  minimize(likelihood, c_0, args=(data.drop(columns='choice').values, draws, verbose), method=method, callback=logging)
#     114         except:
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     594     elif meth == 'bfgs':
# --> 595         return _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     596     elif meth == 'newton-cg':
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, **unknown_options)
#     989                      _line_search_wolfe12(f, myfprime, xk, pk, gfk,
# --> 990                                           old_fval, old_old_fval, amin=1e-100, amax=1e100)
#     991         except _LineSearchError:
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in _line_search_wolfe12(f, fprime, xk, pk, gfk, old_fval, old_old_fval, **kwargs)
#     809                              old_fval, old_old_fval,
# --> 810                              **kwargs)
#     811
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py in line_search_wolfe1(f, fprime, xk, pk, gfk, old_fval, old_old_fval, args, c1, c2, amax, amin, xtol)
#     100             phi, derphi, old_fval, old_old_fval, derphi0,
# --> 101             c1=c1, c2=c2, amax=amax, amin=amin, xtol=xtol)
#     102
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py in scalar_search_wolfe1(phi, derphi, phi0, old_phi0, derphi0, c1, c2, amax, amin, xtol)
#     173             alpha1 = stp
# --> 174             phi1 = phi(stp)
#     175             derphi1 = derphi(stp)
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py in phi(s)
#      86         fc[0] += 1
# ---> 87         return f(xk + s*pk, *args)
#      88
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     299         ncalls[0] += 1
# --> 300         return function(*(wrapper_args + args))
#     301
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-1-6fa405d86610> in <module>
#       5 dataset = datasetloader("n 1000 - seed 1234 - time 2019-06-19-154935.pickle")
#       6
# ----> 7 mixedlogit = Mixedlogit(dataset, "bigbatch").fit(drawtype="pseudo", n_draws=500, verbose=1, save="Big", start=250, end=500)
#
# ~\Code\mixedlogit\src\main.py in fit(self, drawtype, n_draws, start, end, c_0, save, method, verbose)
#      52             for i in range(n_runs):
#      53                 print("Fitting model %d of %d \n" % ((i+1), n_runs))
# ---> 54                 self.result[i] = mixedlogit(self.data[i], drawtype, n_draws, true_c = self.coefficients, dgp= self.dgp, dgp_i = (start+i), dgp_n=len(self.data), verbose = verbose)
#      55
#      56                 if save != False:
#
# ~\Code\mixedlogit\src\optimize.py in mixedlogit(data, drawtype, n_draws, true_c, dgp, dgp_i, dgp_n, c_0, method, verbose)
#     113             res =  minimize(likelihood, c_0, args=(data.drop(columns='choice').values, draws, verbose), method=method, callback=logging)
#     114         except:
# --> 115             res =  minimize(likelihood, c_0, args=(data.drop(columns='choice').values, draws, verbose), method=method, callback=logging)
#     116         end = time.time()
#     117         duration = end-start
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     593         return _minimize_cg(fun, x0, args, jac, callback, **options)
#     594     elif meth == 'bfgs':
# --> 595         return _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     596     elif meth == 'newton-cg':
#     597         return _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, **unknown_options)
#     988             alpha_k, fc, gc, old_fval, old_old_fval, gfkp1 = \
#     989                      _line_search_wolfe12(f, myfprime, xk, pk, gfk,
# --> 990                                           old_fval, old_old_fval, amin=1e-100, amax=1e100)
#     991         except _LineSearchError:
#     992             # Line search failed to find a better solution.
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in _line_search_wolfe12(f, fprime, xk, pk, gfk, old_fval, old_old_fval, **kwargs)
#     808     ret = line_search_wolfe1(f, fprime, xk, pk, gfk,
#     809                              old_fval, old_old_fval,
# --> 810                              **kwargs)
#     811
#     812     if ret[0] is not None and extra_condition is not None:
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py in line_search_wolfe1(f, fprime, xk, pk, gfk, old_fval, old_old_fval, args, c1, c2, amax, amin, xtol)
#      99     stp, fval, old_fval = scalar_search_wolfe1(
#     100             phi, derphi, old_fval, old_old_fval, derphi0,
# --> 101             c1=c1, c2=c2, amax=amax, amin=amin, xtol=xtol)
#     102
#     103     return stp, fc[0], gc[0], fval, old_fval, gval[0]
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py in scalar_search_wolfe1(phi, derphi, phi0, old_phi0, derphi0, c1, c2, amax, amin, xtol)
#     172         if task[:2] == b'FG':
#     173             alpha1 = stp
# --> 174             phi1 = phi(stp)
#     175             derphi1 = derphi(stp)
#     176         else:
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py in phi(s)
#      85     def phi(s):
#      86         fc[0] += 1
# ---> 87         return f(xk + s*pk, *args)
#      88
#      89     def derphi(s):
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     298     def function_wrapper(*wrapper_args):
#     299         ncalls[0] += 1
# --> 300         return function(*(wrapper_args + args))
#     301
#     302     return ncalls, function_wrapper
#
# ZeroDivisionError: division by zero
